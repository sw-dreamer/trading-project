# %%
import pandas as pd
import io

# 1. TradingClient
trading_client_data = {
    '메서드/클래스': [
        'TradingClient.__init__',
        'get_account',
        'get_orders',
        'get_order_by_id',
        'get_order_by_client_id',
        'submit_order',
        'cancel_orders',
        'cancel_order_by_id',
        'replace_order',
        'get_positions',
        'get_position',
        'close_position',
        'close_all_positions',
        'get_assets',
        'get_asset',
        'get_clock',
        'get_calendar',
        'get_watchlists',
        'get_watchlist',
        'create_watchlist',
        'update_watchlist',
        'add_to_watchlist',
        'delete_from_watchlist',
        'delete_watchlist',
        'get_portfolio_history'
    ],
    '설명': [
        '트레이딩 API와 상호작용하기 위한 클라이언트 초기화 (실제 거래 및 페이퍼 트레이딩 모드)',
        '계정 세부 정보 조회',
        '주문 목록 조회 또는 필터링된 주문 목록 가져오기',
        '주문 ID로 특정 주문 조회',
        '클라이언트 주문 ID로 특정 주문 조회',
        '시장에 주문 제출',
        '모든 대기 중인 주문 취소',
        '특정 ID의 주문 취소',
        '기존 주문 수정',
        '모든 포지션 조회',
        '특정 심볼의 포지션 조회',
        '특정 포지션 청산',
        '모든 포지션 청산',
        '거래 가능한 자산 목록 조회',
        '특정 심볼 또는 자산 ID로 자산 조회',
        '현재 시장 시계 조회',
        '거래 일정 조회',
        '모든 관심 목록 조회',
        '특정 관심 목록 조회',
        '새 관심 목록 생성',
        '관심 목록 업데이트',
        '관심 목록에 자산 추가',
        '관심 목록에서 자산 삭제',
        '관심 목록 삭제',
        '포트폴리오 이력 조회'
    ],
    '매개변수': [
        'api_key, secret_key, oauth_token, paper=True (페이퍼 트레이딩 사용 여부), raw_data=False, url_override=None',
        '없음',
        'status, limit, direction, nested, symbols, after, until',
        'order_id',
        'client_order_id',
        'order_data (OrderRequest 객체)',
        '없음',
        'order_id',
        'order_id, qty, time_in_force, limit_price, stop_price, trail_percent, client_order_id',
        '없음',
        'symbol_or_asset_id',
        'symbol_or_asset_id, qty, percentage',
        'cancel_orders',
        'status, asset_class, exchange',
        'symbol_or_asset_id',
        '없음',
        'start, end',
        '없음',
        'watchlist_id',
        'name, symbols',
        'watchlist_id, name, symbols',
        'watchlist_id, symbol',
        'watchlist_id, symbol',
        'watchlist_id',
        'date_start, date_end, period, timeframe, extended_hours'
    ],
    '반환값': [
        'TradingClient 객체',
        'Account 객체',
        'Order 객체 리스트',
        'Order 객체',
        'Order 객체',
        'Order 객체',
        '없음',
        '없음',
        'Order 객체',
        'Position 객체 리스트',
        'Position 객체',
        'Position 객체',
        'ClosePositionResponse 객체 리스트',
        'Asset 객체 리스트',
        'Asset 객체',
        'Clock 객체',
        'Calendar 객체 리스트',
        'Watchlist 객체 리스트',
        'Watchlist 객체',
        'Watchlist 객체',
        'Watchlist 객체',
        'Watchlist 객체',
        '없음',
        '없음',
        'PortfolioHistory 객체'
    ]
}

df_trading_client = pd.DataFrame(trading_client_data)

# 2. 주문 요청 모델
order_request_models = {
    '클래스': [
        'OrderRequest',
        'MarketOrderRequest',
        'LimitOrderRequest',
        'StopOrderRequest',
        'StopLimitOrderRequest',
        'TrailingStopOrderRequest',
        'TakeProfitRequest',
        'StopLossRequest',
        'GetOrdersRequest',
        'GetOrderByIdRequest',
        'ReplaceOrderRequest',
        'OptionLegRequest',
        'ClosePositionRequest'
    ],
    '설명': [
        '주문 요청의 기본 클래스',
        '시장가 주문을 제출하기 위한 요청 모델',
        '지정가 주문을 제출하기 위한 요청 모델',
        '스탑 주문을 제출하기 위한 요청 모델',
        '스탑-리밋 주문을 제출하기 위한 요청 모델',
        '트레일링 스탑 주문을 제출하기 위한 요청 모델',
        '이익 실현 주문을 설정하기 위한 요청 모델',
        '손절매 주문을 설정하기 위한 요청 모델',
        '주문 목록을 필터링하기 위한 요청 모델',
        'ID로 주문을 조회하기 위한 요청 모델',
        '기존 주문을 수정하기 위한 요청 모델',
        '옵션 주문에 대한 다리(leg) 요청 모델',
        '포지션을 청산하기 위한 요청 모델'
    ],
    '주요 매개변수': [
        'symbol, qty, notional, side, type, time_in_force, order_class',
        'symbol, qty, notional, side, time_in_force, client_order_id, extended_hours, order_class, take_profit, stop_loss',
        'symbol, qty, notional, side, time_in_force, limit_price, client_order_id, extended_hours, order_class, take_profit, stop_loss',
        'symbol, qty, notional, side, time_in_force, stop_price, client_order_id, order_class, take_profit, stop_loss',
        'symbol, qty, notional, side, time_in_force, limit_price, stop_price, client_order_id, order_class, take_profit, stop_loss',
        'symbol, qty, notional, side, time_in_force, trail_percent, trail_price, client_order_id, order_class, take_profit, stop_loss',
        'limit_price',
        'stop_price, limit_price',
        'status, limit, direction, nested, symbols, after, until',
        'order_id',
        'qty, time_in_force, limit_price, stop_price, trail, client_order_id',
        'symbol, side, ratio, option_type, strike_price, expiry',
        'qty, percentage'
    ]
}

df_order_request_models = pd.DataFrame(order_request_models)

# 3. 자산 및 포지션 모델
asset_position_models = {
    '클래스': [
        'Asset',
        'Position',
        'Order',
        'Account',
        'Watchlist',
        'Clock',
        'Calendar',
        'PortfolioHistory'
    ],
    '설명': [
        '거래 가능한 자산 정보를 담는 모델',
        '계정이 보유한 포지션 정보를 담는 모델',
        '주문 정보를 담는 모델',
        '계정 정보를 담는 모델',
        '관심 목록 정보를 담는 모델',
        '시장 시계 정보를 담는 모델',
        '거래 일정 정보를 담는 모델',
        '포트폴리오 이력 정보를 담는 모델'
    ],
    '주요 속성': [
        'id, symbol, name, asset_class, exchange, status, tradable, marginable, shortable, easy_to_borrow',
        'asset_id, symbol, qty, avg_entry_price, market_value, cost_basis, unrealized_pl, unrealized_plpc, current_price, side',
        'id, client_order_id, created_at, updated_at, submitted_at, filled_at, expired_at, canceled_at, failed_at, asset_id, symbol, asset_class, qty, filled_qty, type, side, time_in_force, limit_price, stop_price, status',
        'id, status, currency, cash, portfolio_value, buying_power, pattern_day_trader, trading_blocked, transfers_blocked, account_blocked, created_at, shorting_enabled, multiplier, equity, last_equity, long_market_value, short_market_value, initial_margin, maintenance_margin, last_maintenance_margin, daytrading_buying_power, regt_buying_power, non_marginable_buying_power, sma, daytrade_count',
        'id, name, account_id, created_at, updated_at, assets',
        'timestamp, is_open, next_open, next_close',
        'date, open, close, session_open, session_close',
        'timestamp, equity, profit_loss, profit_loss_pct, base_value, timeframe'
    ]
}

df_asset_position_models = pd.DataFrame(asset_position_models)

# 4. 열거형
enums_data = {
    '열거형': [
        'OrderClass',
        'OrderClass.SIMPLE',
        'OrderClass.BRACKET',
        'OrderClass.OCO',
        'OrderClass.OTO',
        'OrderClass.MLEG',
        'OrderType',
        'OrderType.MARKET',
        'OrderType.LIMIT',
        'OrderType.STOP',
        'OrderType.STOP_LIMIT',
        'OrderType.TRAILING_STOP',
        'OrderSide',
        'OrderSide.BUY',
        'OrderSide.SELL',
        'TimeInForce',
        'TimeInForce.DAY',
        'TimeInForce.GTC',
        'TimeInForce.OPG',
        'TimeInForce.CLS',
        'TimeInForce.IOC',
        'TimeInForce.FOK',
        'OrderStatus',
        'OrderStatus.NEW',
        'OrderStatus.PARTIALLY_FILLED',
        'OrderStatus.FILLED',
        'OrderStatus.DONE_FOR_DAY',
        'OrderStatus.CANCELED',
        'OrderStatus.EXPIRED',
        'OrderStatus.REPLACED',
        'OrderStatus.PENDING_CANCEL',
        'OrderStatus.PENDING_REPLACE',
        'OrderStatus.ACCEPTED',
        'OrderStatus.PENDING_NEW',
        'OrderStatus.ACCEPTED_FOR_BIDDING',
        'OrderStatus.STOPPED',
        'OrderStatus.REJECTED',
        'OrderStatus.SUSPENDED',
        'OrderStatus.CALCULATED',
        'AssetClass',
        'AssetClass.US_EQUITY',
        'AssetClass.CRYPTO',
        'AssetClass.OPTION',
        'AssetStatus',
        'AssetStatus.ACTIVE',
        'AssetStatus.INACTIVE'
    ],
    '설명': [
        '주문 클래스 열거형',
        '단순 주문 (기본값)',
        '브라켓 주문 (이익실현 및 손절매 설정이 있는 주문)',
        'OCO(One-Cancels-Other) 주문',
        'OTO(One-Triggers-Other) 주문',
        '다중 레그 주문 (옵션 주문용)',
        '주문 유형 열거형',
        '시장가 주문',
        '지정가 주문',
        '스탑 주문',
        '스탑-리밋 주문',
        '트레일링 스탑 주문',
        '주문 측 열거형',
        '매수 주문',
        '매도 주문',
        '주문 유효 기간 열거형',
        '당일 유효 (장 마감 시 취소)',
        '취소될 때까지 유효',
        '장 시작 시 주문',
        '장 마감 시 주문',
        '즉시 체결 아니면 취소',
        '전체 체결 아니면 취소',
        '주문 상태 열거형',
        '새 주문',
        '부분 체결',
        '전체 체결',
        '당일 거래 완료',
        '취소됨',
        '만료됨',
        '대체됨',
        '취소 대기 중',
        '대체 대기 중',
        '접수됨',
        '신규 대기 중',
        '입찰 접수됨',
        '정지됨',
        '거부됨',
        '정지됨',
        '계산됨',
        '자산 클래스 열거형',
        '미국 주식',
        '암호화폐',
        '옵션',
        '자산 상태 열거형',
        '활성화됨',
        '비활성화됨'
    ],
    '값': [
        '열거형',
        '"simple"',
        '"bracket"',
        '"oco"',
        '"oto"',
        '"mleg"',
        '열거형',
        '"market"',
        '"limit"',
        '"stop"',
        '"stop_limit"',
        '"trailing_stop"',
        '열거형',
        '"buy"',
        '"sell"',
        '열거형',
        '"day"',
        '"gtc"',
        '"opg"',
        '"cls"',
        '"ioc"',
        '"fok"',
        '열거형',
        '"new"',
        '"partially_filled"',
        '"filled"',
        '"done_for_day"',
        '"canceled"',
        '"expired"',
        '"replaced"',
        '"pending_cancel"',
        '"pending_replace"',
        '"accepted"',
        '"pending_new"',
        '"accepted_for_bidding"',
        '"stopped"',
        '"rejected"',
        '"suspended"',
        '"calculated"',
        '열거형',
        '"us_equity"',
        '"crypto"',
        '"option"',
        '열거형',
        '"active"',
        '"inactive"'
    ]
}

df_enums = pd.DataFrame(enums_data)

# 5. TradingStream
trading_stream_data = {
    '메서드/클래스': [
        'TradingStream.__init__',
        'subscribe_trade_updates',
        'unsubscribe_trade_updates',
        'run'
    ],
    '설명': [
        '트레이딩 이벤트에 대한 실시간 업데이트를 받기 위한 웹소켓 클라이언트 초기화',
        '트레이드 업데이트에 대한 구독 설정',
        '트레이드 업데이트 구독 취소',
        '웹소켓 연결 시작 및 이벤트 수신'
    ],
    '매개변수': [
        'api_key, secret_key, oauth_token, raw_data=False, url_override=None, websocket_params=None',
        'handler (async function)',
        '없음',
        '없음'
    ],
    '반환값': [
        'TradingStream 객체',
        '없음',
        '없음',
        '없음'
    ]
}

df_trading_stream = pd.DataFrame(trading_stream_data)

# Excel 파일 생성
output = io.BytesIO()
with pd.ExcelWriter(output, engine='xlsxwriter') as writer:
    df_trading_client.to_excel(writer, sheet_name='트레이딩 클라이언트', index=False)
    df_order_request_models.to_excel(writer, sheet_name='주문 요청 모델', index=False)
    df_asset_position_models.to_excel(writer, sheet_name='자산 및 포지션 모델', index=False)
    df_enums.to_excel(writer, sheet_name='열거형', index=False)
    df_trading_stream.to_excel(writer, sheet_name='트레이딩 스트림', index=False)
    
    # 모든 시트 서식 지정
    for sheet_name in writer.sheets:
        worksheet = writer.sheets[sheet_name]
        # 열 너비 설정
        worksheet.set_column('A:A', 30)  # 첫 번째 열
        worksheet.set_column('B:B', 50)  # 두 번째 열
        worksheet.set_column('C:C', 60)  # 세 번째 열
        worksheet.set_column('D:D', 30)  # 네 번째 열

# 엑셀 파일 저장
output.seek(0)
with open('alpaca_trading_api_korean.xlsx', 'wb') as f:
    f.write(output.getvalue())
