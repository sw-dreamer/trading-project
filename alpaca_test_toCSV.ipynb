# %%
# API_KEY = "PK13HT6JQJGE7IWZ9H10"
# SECRET_KEY = "0a90i4QBy0Z0cViVPYGAmuiziuyrIGsmgQIpqT6c"
# pip install alpaca-py pandas pytz

import os
import time
import pandas as pd
from alpaca.data import StockHistoricalDataClient, StockBarsRequest, TimeFrame
from alpaca.trading import TradingClient
from datetime import datetime, timedelta
import pytz
import logging
import threading

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# API 키 설정
API_KEY = "PK13HT6JQJGE7IWZ9H10" # API_KEY
API_SECRET = "0a90i4QBy0Z0cViVPYGAmuiziuyrIGsmgQIpqT6c" # API_SECRET

# 데이터 클라이언트 생성
data_client = StockHistoricalDataClient(API_KEY, API_SECRET)

# 거래 클라이언트 생성 (시장 시간 확인용)
trading_client = TradingClient(API_KEY, API_SECRET)

# 모니터링할 주식 심볼 목록
SYMBOLS = [
    # Basic Materials
    "VALE", "NEM", "FCX",
    # Communication Services
    "T", "NFLX", "WBD",
    # Consumer Cyclical
    "TSLA", "AMZN", "NKE",
    # Consumer Defensive
    "PEP", "KVUE", "PM",
    # Energy
    "PBR", "KMI", "SHEL",
    # Financial Services
    "ITUB", "USB", "MUFG",
    # Healthcare
    "AZN", "ABT", "UNH",
    # Industrials
    "CSX", "BA", "RTX",
    # Technology
    "NVDA", "ERIC", "YMM",
    # Utilities
    "NEE"
    ,"AAPL"
]

# 최근 데이터 저장용 딕셔너리 (심볼별 데이터 히스토리 유지)
# {symbol: [{timestamp, open, high, low, close, volume}, ...], ...}
historical_data = {symbol: [] for symbol in SYMBOLS}

def get_1min_bars_for_minute(target_minute):
    """특정 시점의 1분봉 데이터를 가져옵니다."""
    # 타겟 시간 (이전 1분간의 데이터)
    end = target_minute
    start = end - timedelta(minutes=1)
    
    # 디버깅용 로그
    logger.info(f"요청 시간 범위: {start} ~ {end} (뉴욕 시간)")
    
    # 요청 설정
    request_params = StockBarsRequest(
        symbol_or_symbols=SYMBOLS,
        timeframe=TimeFrame.Minute,
        start=start,
        end=end,
        adjustment='raw',
        feed='iex'  # 무료 피드 사용
    )

    try:
        # 데이터 요청
        bars = data_client.get_stock_bars(request_params)
        
        # 데이터프레임으로 변환
        df = bars.df
        
        if df is not None and not df.empty:
            bar_count = 0
            # 각 심볼별로 데이터 처리
            for symbol in SYMBOLS:
                try:
                    # 해당 심볼의 데이터만 필터링
                    symbol_data = df.xs(symbol, level=0) if symbol in df.index.get_level_values(0) else None
                    
                    if symbol_data is not None and not symbol_data.empty:
                        # 해당 기간의 봉 데이터 찾기
                        # 시간 필터링 - 타겟 시간에 가장 가까운 봉 선택
                        closest_bar = symbol_data.iloc[-1]
                        bar_time = closest_bar.name
                        
                        # 데이터 저장
                        bar_data = {
                            'timestamp': bar_time,
                            'open': closest_bar['open'],
                            'high': closest_bar['high'],
                            'low': closest_bar['low'],
                            'close': closest_bar['close'],
                            'volume': closest_bar['volume']
                        }
                        
                        # 히스토리에 데이터 추가
                        historical_data[symbol].append(bar_data)
                        
                        # 필요 시 히스토리 크기 제한 (예: 최근 100개만 유지)
                        if len(historical_data[symbol]) > 100:
                            historical_data[symbol] = historical_data[symbol][-100:]
                        
                        bar_count += 1
                    else:
                        logger.warning(f"{symbol}에 대한 데이터가 없습니다.")
                except KeyError:
                    logger.warning(f"{symbol}에 대한 데이터가 없습니다.")
                except Exception as e:
                    logger.error(f"{symbol} 데이터 처리 중 오류: {e}")
            
            logger.info(f"총 {bar_count}개 종목의 1분봉 데이터를 성공적으로 가져왔습니다.")
            return True
        else:
            logger.warning(f"해당 시간대({start} ~ {end})의 데이터가 없습니다. 시장이 열려있는지 확인하세요.")
            return False
    except Exception as e:
        logger.error(f"데이터 요청 중 오류 발생: {e}")
        return False

def check_market_open():
    """시장이 열려있는지 확인합니다."""
    try:
        clock = trading_client.get_clock()
        is_open = clock.is_open
        if is_open:
            next_close = clock.next_close.replace(tzinfo=pytz.UTC)
            next_close_local = next_close.astimezone(pytz.timezone('America/New_York'))
            logger.info(f"시장 열림. 마감 예정 시간: {next_close_local} (뉴욕 시간)")
        else:
            next_open = clock.next_open.replace(tzinfo=pytz.UTC)
            next_open_local = next_open.astimezone(pytz.timezone('America/New_York'))
            logger.info(f"시장 닫힘. 개장 예정 시간: {next_open_local} (뉴욕 시간)")
        return is_open
    except Exception as e:
        logger.error(f"시장 상태 확인 오류: {e}")
        return False

def print_latest_data():
    """가장 최근에 저장된 데이터를 출력합니다."""
    # 현재 시간 (뉴욕 시간)
    ny_time = datetime.now(pytz.timezone('America/New_York'))
    logger.info(f"현재 시간 (뉴욕): {ny_time}")
    logger.info("=" * 60)
    
    # 모든 티커 데이터 출력 (알파벳 순)
    for symbol in sorted(SYMBOLS):
        if historical_data[symbol] and len(historical_data[symbol]) > 0:
            latest = historical_data[symbol][-1]
            logger.info(f"{symbol:<5} - 시간: {latest['timestamp']}, 시가: ${latest['open']:.2f}, 고가: ${latest['high']:.2f}, 저가: ${latest['low']:.2f}, 종가: ${latest['close']:.2f}, 거래량: {latest['volume']}")
        else:
            logger.info(f"{symbol:<5} - 데이터 없음")
    
    logger.info("=" * 60)

def wait_until_next_minute():
    """다음 분의 정각(00초)까지 대기합니다."""
    now = datetime.now()
    
    # 현재 초가 55초 이상이면 다다음 분의 정각까지 대기 (API 지연 고려)
    if now.second >= 55:
        target = now + timedelta(minutes=2)
    else:
        target = now + timedelta(minutes=1)
    
    target = target.replace(second=0, microsecond=0)
    
    wait_seconds = (target - now).total_seconds()
    logger.info(f"다음 데이터 수집 시간({target.strftime('%H:%M:%S')})까지 {wait_seconds:.1f}초 대기...")
    
    return target, wait_seconds

def save_to_csv(minute_time):
    """특정 시점의 모든 종목 데이터를 CSV 파일로 저장합니다."""
    try:
        # 데이터를 DataFrame으로 변환
        rows = []
        for symbol in SYMBOLS:
            if historical_data[symbol] and len(historical_data[symbol]) > 0:
                # 최신 데이터
                data = historical_data[symbol][-1]
                
                row = {
                    'symbol': symbol,
                    'timestamp': data['timestamp'],
                    'open': data['open'],
                    'high': data['high'],
                    'low': data['low'],
                    'close': data['close'],
                    'volume': data['volume']
                }
                rows.append(row)
        
        if not rows:
            logger.warning("저장할 데이터가 없습니다.")
            return
            
        df = pd.DataFrame(rows)
        
        # 시간을 파일명에 포함
        time_str = minute_time.strftime('%Y%m%d_%H%M')
        filename = f"stock_data_{time_str}.csv"
        
        df.to_csv(filename, index=False)
        logger.info(f"데이터가 {filename}에 저장되었습니다.")
    except Exception as e:
        logger.error(f"CSV 저장 중 오류: {e}")

def main():
    logger.info(f"{len(SYMBOLS)}개 종목 실시간 1분봉 데이터 수집 시작...")
    logger.info("매 분 정각(00초)에 이전 1분간의 데이터를 수집합니다.")
    
    try:
        while True:
            is_market_open = check_market_open()
            
            if is_market_open:
                # 다음 분의 정각까지 대기
                target_time, wait_seconds = wait_until_next_minute()
                
                if wait_seconds > 0:
                    time.sleep(wait_seconds)
                
                # 뉴욕 시간대로 변환 (Alpaca API는 뉴욕 시간 기준)
                ny_timezone = pytz.timezone('America/New_York')
                target_time_ny = datetime.now().astimezone(ny_timezone).replace(second=0, microsecond=0)
                
                # 이전 1분간의 데이터 가져오기 (현재 시간 기준 이전 1분)
                previous_minute = target_time_ny - timedelta(minutes=1)
                
                logger.info(f"=== {target_time_ny.strftime('%H:%M')}에 {previous_minute.strftime('%H:%M')}의 1분봉 데이터 수집 중... ===")
                success = get_1min_bars_for_minute(target_time_ny)
                
                if success:
                    # 데이터 출력 및 저장
                    print_latest_data()
                    save_to_csv(target_time_ny)
                    
                # 데이터 수집 후 약간의 지연 (API 요청 간 간격 유지)
                time.sleep(1)
            else:
                logger.warning("현재 미국 주식 시장이 닫혀 있습니다.")
                # 15분마다 시장 상태 확인
                time.sleep(900)
            
    except KeyboardInterrupt:
        logger.info("프로그램을 종료합니다.")

if __name__ == "__main__":
    main()
# Out:
# 2025-05-15 23:24:00,001 - INFO - === 10:24에 10:23의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:24:00,001 - INFO - 요청 시간 범위: 2025-05-15 10:23:00-04:00 ~ 2025-05-15 10:24:00-04:00 (뉴욕 시간)
# 2025-05-15 23:24:00,866 - WARNING - VALE에 대한 데이터가 없습니다.
# 2025-05-15 23:24:00,870 - WARNING - NFLX에 대한 데이터가 없습니다.
# 2025-05-15 23:24:00,874 - WARNING - PBR에 대한 데이터가 없습니다.
# 2025-05-15 23:24:00,876 - WARNING - SHEL에 대한 데이터가 없습니다.
# 2025-05-15 23:24:00,877 - WARNING - USB에 대한 데이터가 없습니다.
# 2025-05-15 23:24:00,883 - WARNING - ERIC에 대한 데이터가 없습니다.
# 2025-05-15 23:24:00,885 - INFO - 총 23개 종목의 1분봉 데이터를 성공적으로 가져왔습니다.
# 2025-05-15 23:24:00,886 - INFO - 현재 시간 (뉴욕): 2025-05-15 10:24:00.886279-04:00
# 2025-05-15 23:24:00,887 - INFO - ============================================================
# 2025-05-15 23:24:00,888 - INFO - AAPL  - 시간: 2025-05-15 14:23:00+00:00, 시가: $210.18, 고가: $210.35, 저가: $210.17, 종가: $210.32, 거래량: 2259.0
# 2025-05-15 23:24:00,888 - INFO - ABT   - 시간: 2025-05-15 14:23:00+00:00, 시가: $132.06, 고가: $132.06, 저가: $131.98, 종가: $132.02, 거래량: 2090.0
# 2025-05-15 23:24:00,889 - INFO - AMZN  - 시간: 2025-05-15 14:23:00+00:00, 시가: $205.10, 고가: $205.44, 저가: $205.10, 종가: $205.41, 거래량: 2029.0
# 2025-05-15 23:24:00,890 - INFO - AZN   - 시간: 2025-05-15 14:23:00+00:00, 시가: $67.20, 고가: $67.20, 저가: $67.13, 종가: $67.13, 거래량: 862.0
# 2025-05-15 23:24:00,890 - INFO - BA    - 시간: 2025-05-15 14:23:00+00:00, 시가: $207.42, 고가: $207.42, 저가: $207.42, 종가: $207.42, 거래량: 201.0
# 2025-05-15 23:24:00,891 - INFO - CSX   - 시간: 2025-05-15 14:23:00+00:00, 시가: $30.98, 고가: $30.98, 저가: $30.96, 종가: $30.96, 거래량: 1382.0
# 2025-05-15 23:24:00,892 - INFO - ERIC  - 데이터 없음
# 2025-05-15 23:24:00,892 - INFO - FCX   - 시간: 2025-05-15 14:23:00+00:00, 시가: $37.99, 고가: $37.99, 저가: $37.98, 종가: $37.98, 거래량: 1526.0
# 2025-05-15 23:24:00,894 - INFO - ITUB  - 시간: 2025-05-15 14:23:00+00:00, 시가: $6.67, 고가: $6.67, 저가: $6.67, 종가: $6.67, 거래량: 26787.0
# 2025-05-15 23:24:00,896 - INFO - KMI   - 시간: 2025-05-15 14:23:00+00:00, 시가: $27.75, 고가: $27.75, 저가: $27.75, 종가: $27.75, 거래량: 507.0
# 2025-05-15 23:24:00,897 - INFO - KVUE  - 시간: 2025-05-15 14:23:00+00:00, 시가: $23.91, 고가: $23.92, 저가: $23.89, 종가: $23.91, 거래량: 8072.0
# 2025-05-15 23:24:00,898 - INFO - MUFG  - 시간: 2025-05-15 14:23:00+00:00, 시가: $13.29, 고가: $13.29, 저가: $13.29, 종가: $13.29, 거래량: 1142.0
# 2025-05-15 23:24:00,899 - INFO - NEE   - 시간: 2025-05-15 14:23:00+00:00, 시가: $73.84, 고가: $73.87, 저가: $73.80, 종가: $73.84, 거래량: 2141.0
# 2025-05-15 23:24:00,900 - INFO - NEM   - 시간: 2025-05-15 14:23:00+00:00, 시가: $48.98, 고가: $49.01, 저가: $48.96, 종가: $49.01, 거래량: 1011.0
# 2025-05-15 23:24:00,901 - INFO - NFLX  - 데이터 없음
# 2025-05-15 23:24:00,902 - INFO - NKE   - 시간: 2025-05-15 14:23:00+00:00, 시가: $62.00, 고가: $62.02, 저가: $61.98, 종가: $61.99, 거래량: 2400.0
# 2025-05-15 23:24:00,903 - INFO - NVDA  - 시간: 2025-05-15 14:23:00+00:00, 시가: $133.72, 고가: $133.82, 저가: $133.72, 종가: $133.79, 거래량: 2078.0
# 2025-05-15 23:24:00,904 - INFO - PBR   - 데이터 없음
# 2025-05-15 23:24:00,906 - INFO - PEP   - 시간: 2025-05-15 14:23:00+00:00, 시가: $129.82, 고가: $129.85, 저가: $129.82, 종가: $129.83, 거래량: 664.0
# 2025-05-15 23:24:00,907 - INFO - PM    - 시간: 2025-05-15 14:23:00+00:00, 시가: $168.02, 고가: $168.03, 저가: $168.02, 종가: $168.03, 거래량: 535.0
# 2025-05-15 23:24:00,907 - INFO - RTX   - 시간: 2025-05-15 14:23:00+00:00, 시가: $133.00, 고가: $133.10, 저가: $132.97, 종가: $133.10, 거래량: 1416.0
# 2025-05-15 23:24:00,908 - INFO - SHEL  - 데이터 없음
# 2025-05-15 23:24:00,909 - INFO - T     - 시간: 2025-05-15 14:23:00+00:00, 시가: $27.09, 고가: $27.09, 저가: $27.07, 종가: $27.08, 거래량: 4058.0
# 2025-05-15 23:24:00,910 - INFO - TSLA  - 시간: 2025-05-15 14:23:00+00:00, 시가: $340.09, 고가: $340.25, 저가: $339.97, 종가: $340.00, 거래량: 1639.0
# 2025-05-15 23:24:00,911 - INFO - UNH   - 시간: 2025-05-15 14:23:00+00:00, 시가: $257.00, 고가: $257.15, 저가: $255.17, 종가: $255.43, 거래량: 7957.0
# 2025-05-15 23:24:00,912 - INFO - USB   - 데이터 없음
# 2025-05-15 23:24:00,913 - INFO - VALE  - 데이터 없음
# 2025-05-15 23:24:00,914 - INFO - WBD   - 시간: 2025-05-15 14:23:00+00:00, 시가: $9.12, 고가: $9.13, 저가: $9.12, 종가: $9.12, 거래량: 6447.0
# 2025-05-15 23:24:00,915 - INFO - YMM   - 시간: 2025-05-15 14:23:00+00:00, 시가: $12.48, 고가: $12.49, 저가: $12.48, 종가: $12.49, 거래량: 200.0
# 2025-05-15 23:24:00,916 - INFO - ============================================================
# 2025-05-15 23:24:00,926 - INFO - 데이터가 stock_data_20250515_1024.csv에 저장되었습니다.
# 2025-05-15 23:24:02,123 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:24:02,124 - INFO - 다음 데이터 수집 시간(23:25:00)까지 57.9초 대기...
# 2025-05-15 23:25:00,012 - INFO - === 10:25에 10:24의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:25:00,014 - INFO - 요청 시간 범위: 2025-05-15 10:24:00-04:00 ~ 2025-05-15 10:25:00-04:00 (뉴욕 시간)
# 2025-05-15 23:25:00,213 - WARNING - 해당 시간대(2025-05-15 10:24:00-04:00 ~ 2025-05-15 10:25:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:25:01,407 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:25:01,408 - INFO - 다음 데이터 수집 시간(23:26:00)까지 58.6초 대기...
# 2025-05-15 23:26:00,004 - INFO - === 10:26에 10:25의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:26:00,005 - INFO - 요청 시간 범위: 2025-05-15 10:25:00-04:00 ~ 2025-05-15 10:26:00-04:00 (뉴욕 시간)
# 2025-05-15 23:26:00,204 - WARNING - 해당 시간대(2025-05-15 10:25:00-04:00 ~ 2025-05-15 10:26:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:26:01,392 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:26:01,393 - INFO - 다음 데이터 수집 시간(23:27:00)까지 58.6초 대기...
# 2025-05-15 23:27:00,003 - INFO - === 10:27에 10:26의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:27:00,004 - INFO - 요청 시간 범위: 2025-05-15 10:26:00-04:00 ~ 2025-05-15 10:27:00-04:00 (뉴욕 시간)
# 2025-05-15 23:27:00,203 - WARNING - 해당 시간대(2025-05-15 10:26:00-04:00 ~ 2025-05-15 10:27:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:27:01,399 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:27:01,400 - INFO - 다음 데이터 수집 시간(23:28:00)까지 58.6초 대기...
# 2025-05-15 23:28:00,009 - INFO - === 10:28에 10:27의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:28:00,010 - INFO - 요청 시간 범위: 2025-05-15 10:27:00-04:00 ~ 2025-05-15 10:28:00-04:00 (뉴욕 시간)
# 2025-05-15 23:28:00,215 - WARNING - 해당 시간대(2025-05-15 10:27:00-04:00 ~ 2025-05-15 10:28:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:28:01,409 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:28:01,410 - INFO - 다음 데이터 수집 시간(23:29:00)까지 58.6초 대기...
# 2025-05-15 23:29:00,013 - INFO - === 10:29에 10:28의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:29:00,014 - INFO - 요청 시간 범위: 2025-05-15 10:28:00-04:00 ~ 2025-05-15 10:29:00-04:00 (뉴욕 시간)
# 2025-05-15 23:29:00,216 - WARNING - 해당 시간대(2025-05-15 10:28:00-04:00 ~ 2025-05-15 10:29:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:29:01,400 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:29:01,401 - INFO - 다음 데이터 수집 시간(23:30:00)까지 58.6초 대기...
# 2025-05-15 23:30:00,012 - INFO - === 10:30에 10:29의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:30:00,015 - INFO - 요청 시간 범위: 2025-05-15 10:29:00-04:00 ~ 2025-05-15 10:30:00-04:00 (뉴욕 시간)
# 2025-05-15 23:30:00,218 - WARNING - 해당 시간대(2025-05-15 10:29:00-04:00 ~ 2025-05-15 10:30:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:30:01,415 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:30:01,416 - INFO - 다음 데이터 수집 시간(23:31:00)까지 58.6초 대기...
# 2025-05-15 23:31:00,008 - INFO - === 10:31에 10:30의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:31:00,009 - INFO - 요청 시간 범위: 2025-05-15 10:30:00-04:00 ~ 2025-05-15 10:31:00-04:00 (뉴욕 시간)
# 2025-05-15 23:31:00,218 - WARNING - 해당 시간대(2025-05-15 10:30:00-04:00 ~ 2025-05-15 10:31:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:31:01,406 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:31:01,407 - INFO - 다음 데이터 수집 시간(23:32:00)까지 58.6초 대기...
# 2025-05-15 23:32:00,013 - INFO - === 10:32에 10:31의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:32:00,015 - INFO - 요청 시간 범위: 2025-05-15 10:31:00-04:00 ~ 2025-05-15 10:32:00-04:00 (뉴욕 시간)
# 2025-05-15 23:32:00,221 - WARNING - 해당 시간대(2025-05-15 10:31:00-04:00 ~ 2025-05-15 10:32:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:32:01,413 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:32:01,414 - INFO - 다음 데이터 수집 시간(23:33:00)까지 58.6초 대기...
# 2025-05-15 23:33:00,010 - INFO - === 10:33에 10:32의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:33:00,012 - INFO - 요청 시간 범위: 2025-05-15 10:32:00-04:00 ~ 2025-05-15 10:33:00-04:00 (뉴욕 시간)
# 2025-05-15 23:33:00,212 - WARNING - 해당 시간대(2025-05-15 10:32:00-04:00 ~ 2025-05-15 10:33:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:33:01,410 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:33:01,411 - INFO - 다음 데이터 수집 시간(23:34:00)까지 58.6초 대기...
# 2025-05-15 23:34:00,002 - INFO - === 10:34에 10:33의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:34:00,003 - INFO - 요청 시간 범위: 2025-05-15 10:33:00-04:00 ~ 2025-05-15 10:34:00-04:00 (뉴욕 시간)
# 2025-05-15 23:34:00,204 - WARNING - 해당 시간대(2025-05-15 10:33:00-04:00 ~ 2025-05-15 10:34:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:34:01,402 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:34:01,403 - INFO - 다음 데이터 수집 시간(23:35:00)까지 58.6초 대기...
# 2025-05-15 23:35:00,012 - INFO - === 10:35에 10:34의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:35:00,012 - INFO - 요청 시간 범위: 2025-05-15 10:34:00-04:00 ~ 2025-05-15 10:35:00-04:00 (뉴욕 시간)
# 2025-05-15 23:35:00,216 - WARNING - 해당 시간대(2025-05-15 10:34:00-04:00 ~ 2025-05-15 10:35:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:35:01,414 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:35:01,415 - INFO - 다음 데이터 수집 시간(23:36:00)까지 58.6초 대기...
# 2025-05-15 23:36:00,005 - INFO - === 10:36에 10:35의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:36:00,006 - INFO - 요청 시간 범위: 2025-05-15 10:35:00-04:00 ~ 2025-05-15 10:36:00-04:00 (뉴욕 시간)
# 2025-05-15 23:36:00,206 - WARNING - 해당 시간대(2025-05-15 10:35:00-04:00 ~ 2025-05-15 10:36:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:36:01,404 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:36:01,405 - INFO - 다음 데이터 수집 시간(23:37:00)까지 58.6초 대기...
# 2025-05-15 23:37:00,013 - INFO - === 10:37에 10:36의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:37:00,015 - INFO - 요청 시간 범위: 2025-05-15 10:36:00-04:00 ~ 2025-05-15 10:37:00-04:00 (뉴욕 시간)
# 2025-05-15 23:37:00,214 - WARNING - 해당 시간대(2025-05-15 10:36:00-04:00 ~ 2025-05-15 10:37:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:37:01,499 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:37:01,500 - INFO - 다음 데이터 수집 시간(23:38:00)까지 58.5초 대기...
# 2025-05-15 23:38:00,007 - INFO - === 10:38에 10:37의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:38:00,008 - INFO - 요청 시간 범위: 2025-05-15 10:37:00-04:00 ~ 2025-05-15 10:38:00-04:00 (뉴욕 시간)
# 2025-05-15 23:38:00,208 - WARNING - 해당 시간대(2025-05-15 10:37:00-04:00 ~ 2025-05-15 10:38:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:38:01,393 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:38:01,394 - INFO - 다음 데이터 수집 시간(23:39:00)까지 58.6초 대기...
# 2025-05-15 23:39:00,009 - INFO - === 10:39에 10:38의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:39:00,010 - INFO - 요청 시간 범위: 2025-05-15 10:38:00-04:00 ~ 2025-05-15 10:39:00-04:00 (뉴욕 시간)
# 2025-05-15 23:39:00,209 - WARNING - 해당 시간대(2025-05-15 10:38:00-04:00 ~ 2025-05-15 10:39:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:39:01,409 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:39:01,410 - INFO - 다음 데이터 수집 시간(23:40:00)까지 58.6초 대기...
# 2025-05-15 23:40:00,008 - INFO - === 10:40에 10:39의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:40:00,009 - INFO - 요청 시간 범위: 2025-05-15 10:39:00-04:00 ~ 2025-05-15 10:40:00-04:00 (뉴욕 시간)
# 2025-05-15 23:40:00,206 - WARNING - 해당 시간대(2025-05-15 10:39:00-04:00 ~ 2025-05-15 10:40:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:40:01,397 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:40:01,398 - INFO - 다음 데이터 수집 시간(23:41:00)까지 58.6초 대기...
# 2025-05-15 23:41:00,012 - INFO - === 10:41에 10:40의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:41:00,013 - INFO - 요청 시간 범위: 2025-05-15 10:40:00-04:00 ~ 2025-05-15 10:41:00-04:00 (뉴욕 시간)
# 2025-05-15 23:41:00,210 - WARNING - 해당 시간대(2025-05-15 10:40:00-04:00 ~ 2025-05-15 10:41:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:41:01,401 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:41:01,402 - INFO - 다음 데이터 수집 시간(23:42:00)까지 58.6초 대기...
# 2025-05-15 23:42:00,006 - INFO - === 10:42에 10:41의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:42:00,007 - INFO - 요청 시간 범위: 2025-05-15 10:41:00-04:00 ~ 2025-05-15 10:42:00-04:00 (뉴욕 시간)
# 2025-05-15 23:42:00,208 - WARNING - 해당 시간대(2025-05-15 10:41:00-04:00 ~ 2025-05-15 10:42:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:42:01,413 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:42:01,413 - INFO - 다음 데이터 수집 시간(23:43:00)까지 58.6초 대기...
# 2025-05-15 23:43:00,003 - INFO - === 10:43에 10:42의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:43:00,004 - INFO - 요청 시간 범위: 2025-05-15 10:42:00-04:00 ~ 2025-05-15 10:43:00-04:00 (뉴욕 시간)
# 2025-05-15 23:43:00,202 - WARNING - 해당 시간대(2025-05-15 10:42:00-04:00 ~ 2025-05-15 10:43:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:43:01,393 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:43:01,394 - INFO - 다음 데이터 수집 시간(23:44:00)까지 58.6초 대기...
# 2025-05-15 23:44:00,015 - INFO - === 10:44에 10:43의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:44:00,016 - INFO - 요청 시간 범위: 2025-05-15 10:43:00-04:00 ~ 2025-05-15 10:44:00-04:00 (뉴욕 시간)
# 2025-05-15 23:44:00,219 - WARNING - 해당 시간대(2025-05-15 10:43:00-04:00 ~ 2025-05-15 10:44:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:44:01,416 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:44:01,417 - INFO - 다음 데이터 수집 시간(23:45:00)까지 58.6초 대기...
# 2025-05-15 23:45:00,004 - INFO - === 10:45에 10:44의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:45:00,005 - INFO - 요청 시간 범위: 2025-05-15 10:44:00-04:00 ~ 2025-05-15 10:45:00-04:00 (뉴욕 시간)
# 2025-05-15 23:45:00,204 - WARNING - 해당 시간대(2025-05-15 10:44:00-04:00 ~ 2025-05-15 10:45:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:45:01,389 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:45:01,390 - INFO - 다음 데이터 수집 시간(23:46:00)까지 58.6초 대기...
# 2025-05-15 23:46:00,016 - INFO - === 10:46에 10:45의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:46:00,017 - INFO - 요청 시간 범위: 2025-05-15 10:45:00-04:00 ~ 2025-05-15 10:46:00-04:00 (뉴욕 시간)
# 2025-05-15 23:46:00,221 - WARNING - 해당 시간대(2025-05-15 10:45:00-04:00 ~ 2025-05-15 10:46:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:46:01,416 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:46:01,417 - INFO - 다음 데이터 수집 시간(23:47:00)까지 58.6초 대기...
# 2025-05-15 23:47:00,001 - INFO - === 10:47에 10:46의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:47:00,001 - INFO - 요청 시간 범위: 2025-05-15 10:46:00-04:00 ~ 2025-05-15 10:47:00-04:00 (뉴욕 시간)
# 2025-05-15 23:47:00,201 - WARNING - 해당 시간대(2025-05-15 10:46:00-04:00 ~ 2025-05-15 10:47:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:47:01,391 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:47:01,392 - INFO - 다음 데이터 수집 시간(23:48:00)까지 58.6초 대기...
# 2025-05-15 23:48:00,012 - INFO - === 10:48에 10:47의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:48:00,013 - INFO - 요청 시간 범위: 2025-05-15 10:47:00-04:00 ~ 2025-05-15 10:48:00-04:00 (뉴욕 시간)
# 2025-05-15 23:48:00,213 - WARNING - 해당 시간대(2025-05-15 10:47:00-04:00 ~ 2025-05-15 10:48:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:48:01,402 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:48:01,403 - INFO - 다음 데이터 수집 시간(23:49:00)까지 58.6초 대기...
# 2025-05-15 23:49:00,015 - INFO - === 10:49에 10:48의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:49:00,016 - INFO - 요청 시간 범위: 2025-05-15 10:48:00-04:00 ~ 2025-05-15 10:49:00-04:00 (뉴욕 시간)
# 2025-05-15 23:49:00,214 - WARNING - 해당 시간대(2025-05-15 10:48:00-04:00 ~ 2025-05-15 10:49:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:49:01,406 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:49:01,407 - INFO - 다음 데이터 수집 시간(23:50:00)까지 58.6초 대기...
# 2025-05-15 23:50:00,006 - INFO - === 10:50에 10:49의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:50:00,007 - INFO - 요청 시간 범위: 2025-05-15 10:49:00-04:00 ~ 2025-05-15 10:50:00-04:00 (뉴욕 시간)
# 2025-05-15 23:50:00,207 - WARNING - 해당 시간대(2025-05-15 10:49:00-04:00 ~ 2025-05-15 10:50:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:50:01,406 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:50:01,407 - INFO - 다음 데이터 수집 시간(23:51:00)까지 58.6초 대기...
# 2025-05-15 23:51:00,009 - INFO - === 10:51에 10:50의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:51:00,010 - INFO - 요청 시간 범위: 2025-05-15 10:50:00-04:00 ~ 2025-05-15 10:51:00-04:00 (뉴욕 시간)
# 2025-05-15 23:51:00,222 - WARNING - 해당 시간대(2025-05-15 10:50:00-04:00 ~ 2025-05-15 10:51:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:51:01,412 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:51:01,413 - INFO - 다음 데이터 수집 시간(23:52:00)까지 58.6초 대기...
# 2025-05-15 23:52:00,005 - INFO - === 10:52에 10:51의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:52:00,007 - INFO - 요청 시간 범위: 2025-05-15 10:51:00-04:00 ~ 2025-05-15 10:52:00-04:00 (뉴욕 시간)
# 2025-05-15 23:52:00,208 - WARNING - 해당 시간대(2025-05-15 10:51:00-04:00 ~ 2025-05-15 10:52:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:52:01,393 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:52:01,394 - INFO - 다음 데이터 수집 시간(23:53:00)까지 58.6초 대기...
# 2025-05-15 23:53:00,015 - INFO - === 10:53에 10:52의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:53:00,016 - INFO - 요청 시간 범위: 2025-05-15 10:52:00-04:00 ~ 2025-05-15 10:53:00-04:00 (뉴욕 시간)
# 2025-05-15 23:53:00,213 - WARNING - 해당 시간대(2025-05-15 10:52:00-04:00 ~ 2025-05-15 10:53:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:53:01,407 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:53:01,408 - INFO - 다음 데이터 수집 시간(23:54:00)까지 58.6초 대기...
# 2025-05-15 23:54:00,006 - INFO - === 10:54에 10:53의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:54:00,008 - INFO - 요청 시간 범위: 2025-05-15 10:53:00-04:00 ~ 2025-05-15 10:54:00-04:00 (뉴욕 시간)
# 2025-05-15 23:54:00,211 - WARNING - 해당 시간대(2025-05-15 10:53:00-04:00 ~ 2025-05-15 10:54:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:54:01,397 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:54:01,398 - INFO - 다음 데이터 수집 시간(23:55:00)까지 58.6초 대기...
# 2025-05-15 23:55:00,005 - INFO - === 10:55에 10:54의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:55:00,006 - INFO - 요청 시간 범위: 2025-05-15 10:54:00-04:00 ~ 2025-05-15 10:55:00-04:00 (뉴욕 시간)
# 2025-05-15 23:55:00,207 - WARNING - 해당 시간대(2025-05-15 10:54:00-04:00 ~ 2025-05-15 10:55:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:55:01,401 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:55:01,402 - INFO - 다음 데이터 수집 시간(23:56:00)까지 58.6초 대기...
# 2025-05-15 23:56:00,009 - INFO - === 10:56에 10:55의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:56:00,010 - INFO - 요청 시간 범위: 2025-05-15 10:55:00-04:00 ~ 2025-05-15 10:56:00-04:00 (뉴욕 시간)
# 2025-05-15 23:56:00,220 - WARNING - 해당 시간대(2025-05-15 10:55:00-04:00 ~ 2025-05-15 10:56:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:56:01,418 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:56:01,419 - INFO - 다음 데이터 수집 시간(23:57:00)까지 58.6초 대기...
# 2025-05-15 23:57:00,009 - INFO - === 10:57에 10:56의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:57:00,010 - INFO - 요청 시간 범위: 2025-05-15 10:56:00-04:00 ~ 2025-05-15 10:57:00-04:00 (뉴욕 시간)
# 2025-05-15 23:57:00,209 - WARNING - 해당 시간대(2025-05-15 10:56:00-04:00 ~ 2025-05-15 10:57:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:57:01,401 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:57:01,402 - INFO - 다음 데이터 수집 시간(23:58:00)까지 58.6초 대기...
# 2025-05-15 23:58:00,016 - INFO - === 10:58에 10:57의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:58:00,017 - INFO - 요청 시간 범위: 2025-05-15 10:57:00-04:00 ~ 2025-05-15 10:58:00-04:00 (뉴욕 시간)
# 2025-05-15 23:58:00,217 - WARNING - 해당 시간대(2025-05-15 10:57:00-04:00 ~ 2025-05-15 10:58:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:58:01,416 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:58:01,417 - INFO - 다음 데이터 수집 시간(23:59:00)까지 58.6초 대기...
# 2025-05-15 23:59:00,011 - INFO - === 10:59에 10:58의 1분봉 데이터 수집 중... ===
# 2025-05-15 23:59:00,013 - INFO - 요청 시간 범위: 2025-05-15 10:58:00-04:00 ~ 2025-05-15 10:59:00-04:00 (뉴욕 시간)
# 2025-05-15 23:59:00,223 - WARNING - 해당 시간대(2025-05-15 10:58:00-04:00 ~ 2025-05-15 10:59:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-15 23:59:01,408 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-15 23:59:01,410 - INFO - 다음 데이터 수집 시간(00:00:00)까지 58.6초 대기...
# 2025-05-16 00:00:00,015 - INFO - === 11:00에 10:59의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:00:00,015 - INFO - 요청 시간 범위: 2025-05-15 10:59:00-04:00 ~ 2025-05-15 11:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:00:00,215 - WARNING - 해당 시간대(2025-05-15 10:59:00-04:00 ~ 2025-05-15 11:00:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:00:01,399 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:00:01,400 - INFO - 다음 데이터 수집 시간(00:01:00)까지 58.6초 대기...
# 2025-05-16 00:01:00,011 - INFO - === 11:01에 11:00의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:01:00,012 - INFO - 요청 시간 범위: 2025-05-15 11:00:00-04:00 ~ 2025-05-15 11:01:00-04:00 (뉴욕 시간)
# 2025-05-16 00:01:00,214 - WARNING - 해당 시간대(2025-05-15 11:00:00-04:00 ~ 2025-05-15 11:01:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:01:01,399 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:01:01,400 - INFO - 다음 데이터 수집 시간(00:02:00)까지 58.6초 대기...
# 2025-05-16 00:02:00,009 - INFO - === 11:02에 11:01의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:02:00,010 - INFO - 요청 시간 범위: 2025-05-15 11:01:00-04:00 ~ 2025-05-15 11:02:00-04:00 (뉴욕 시간)
# 2025-05-16 00:02:00,235 - WARNING - 해당 시간대(2025-05-15 11:01:00-04:00 ~ 2025-05-15 11:02:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:02:01,427 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:02:01,428 - INFO - 다음 데이터 수집 시간(00:03:00)까지 58.6초 대기...
# 2025-05-16 00:03:00,012 - INFO - === 11:03에 11:02의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:03:00,013 - INFO - 요청 시간 범위: 2025-05-15 11:02:00-04:00 ~ 2025-05-15 11:03:00-04:00 (뉴욕 시간)
# 2025-05-16 00:03:00,213 - WARNING - 해당 시간대(2025-05-15 11:02:00-04:00 ~ 2025-05-15 11:03:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:03:01,401 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:03:01,401 - INFO - 다음 데이터 수집 시간(00:04:00)까지 58.6초 대기...
# 2025-05-16 00:04:00,009 - INFO - === 11:04에 11:03의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:04:00,010 - INFO - 요청 시간 범위: 2025-05-15 11:03:00-04:00 ~ 2025-05-15 11:04:00-04:00 (뉴욕 시간)
# 2025-05-16 00:04:00,215 - WARNING - 해당 시간대(2025-05-15 11:03:00-04:00 ~ 2025-05-15 11:04:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:04:01,412 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:04:01,413 - INFO - 다음 데이터 수집 시간(00:05:00)까지 58.6초 대기...
# 2025-05-16 00:05:00,013 - INFO - === 11:05에 11:04의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:05:00,015 - INFO - 요청 시간 범위: 2025-05-15 11:04:00-04:00 ~ 2025-05-15 11:05:00-04:00 (뉴욕 시간)
# 2025-05-16 00:05:00,217 - WARNING - 해당 시간대(2025-05-15 11:04:00-04:00 ~ 2025-05-15 11:05:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:05:01,414 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:05:01,415 - INFO - 다음 데이터 수집 시간(00:06:00)까지 58.6초 대기...
# 2025-05-16 00:06:00,005 - INFO - === 11:06에 11:05의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:06:00,006 - INFO - 요청 시간 범위: 2025-05-15 11:05:00-04:00 ~ 2025-05-15 11:06:00-04:00 (뉴욕 시간)
# 2025-05-16 00:06:00,207 - WARNING - 해당 시간대(2025-05-15 11:05:00-04:00 ~ 2025-05-15 11:06:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:06:01,406 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:06:01,407 - INFO - 다음 데이터 수집 시간(00:07:00)까지 58.6초 대기...
# 2025-05-16 00:07:00,013 - INFO - === 11:07에 11:06의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:07:00,015 - INFO - 요청 시간 범위: 2025-05-15 11:06:00-04:00 ~ 2025-05-15 11:07:00-04:00 (뉴욕 시간)
# 2025-05-16 00:07:00,219 - WARNING - 해당 시간대(2025-05-15 11:06:00-04:00 ~ 2025-05-15 11:07:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:07:01,409 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:07:01,410 - INFO - 다음 데이터 수집 시간(00:08:00)까지 58.6초 대기...
# 2025-05-16 00:08:00,007 - INFO - === 11:08에 11:07의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:08:00,008 - INFO - 요청 시간 범위: 2025-05-15 11:07:00-04:00 ~ 2025-05-15 11:08:00-04:00 (뉴욕 시간)
# 2025-05-16 00:08:00,248 - WARNING - 해당 시간대(2025-05-15 11:07:00-04:00 ~ 2025-05-15 11:08:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:08:01,442 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:08:01,443 - INFO - 다음 데이터 수집 시간(00:09:00)까지 58.6초 대기...
# 2025-05-16 00:09:00,009 - INFO - === 11:09에 11:08의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:09:00,009 - INFO - 요청 시간 범위: 2025-05-15 11:08:00-04:00 ~ 2025-05-15 11:09:00-04:00 (뉴욕 시간)
# 2025-05-16 00:09:00,209 - WARNING - 해당 시간대(2025-05-15 11:08:00-04:00 ~ 2025-05-15 11:09:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:09:01,397 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:09:01,398 - INFO - 다음 데이터 수집 시간(00:10:00)까지 58.6초 대기...
# 2025-05-16 00:10:00,013 - INFO - === 11:10에 11:09의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:10:00,015 - INFO - 요청 시간 범위: 2025-05-15 11:09:00-04:00 ~ 2025-05-15 11:10:00-04:00 (뉴욕 시간)
# 2025-05-16 00:10:00,217 - WARNING - 해당 시간대(2025-05-15 11:09:00-04:00 ~ 2025-05-15 11:10:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:10:01,411 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:10:01,412 - INFO - 다음 데이터 수집 시간(00:11:00)까지 58.6초 대기...
# 2025-05-16 00:11:00,006 - INFO - === 11:11에 11:10의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:11:00,007 - INFO - 요청 시간 범위: 2025-05-15 11:10:00-04:00 ~ 2025-05-15 11:11:00-04:00 (뉴욕 시간)
# 2025-05-16 00:11:00,209 - WARNING - 해당 시간대(2025-05-15 11:10:00-04:00 ~ 2025-05-15 11:11:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:11:01,393 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:11:01,394 - INFO - 다음 데이터 수집 시간(00:12:00)까지 58.6초 대기...
# 2025-05-16 00:12:00,008 - INFO - === 11:12에 11:11의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:12:00,009 - INFO - 요청 시간 범위: 2025-05-15 11:11:00-04:00 ~ 2025-05-15 11:12:00-04:00 (뉴욕 시간)
# 2025-05-16 00:12:00,223 - WARNING - 해당 시간대(2025-05-15 11:11:00-04:00 ~ 2025-05-15 11:12:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:12:01,420 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:12:01,421 - INFO - 다음 데이터 수집 시간(00:13:00)까지 58.6초 대기...
# 2025-05-16 00:13:00,012 - INFO - === 11:13에 11:12의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:13:00,013 - INFO - 요청 시간 범위: 2025-05-15 11:12:00-04:00 ~ 2025-05-15 11:13:00-04:00 (뉴욕 시간)
# 2025-05-16 00:13:00,213 - WARNING - 해당 시간대(2025-05-15 11:12:00-04:00 ~ 2025-05-15 11:13:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:13:01,413 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:13:01,413 - INFO - 다음 데이터 수집 시간(00:14:00)까지 58.6초 대기...
# 2025-05-16 00:14:00,010 - INFO - === 11:14에 11:13의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:14:00,012 - INFO - 요청 시간 범위: 2025-05-15 11:13:00-04:00 ~ 2025-05-15 11:14:00-04:00 (뉴욕 시간)
# 2025-05-16 00:14:00,217 - WARNING - 해당 시간대(2025-05-15 11:13:00-04:00 ~ 2025-05-15 11:14:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:14:01,427 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:14:01,427 - INFO - 다음 데이터 수집 시간(00:15:00)까지 58.6초 대기...
# 2025-05-16 00:15:00,002 - INFO - === 11:15에 11:14의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:15:00,004 - INFO - 요청 시간 범위: 2025-05-15 11:14:00-04:00 ~ 2025-05-15 11:15:00-04:00 (뉴욕 시간)
# 2025-05-16 00:15:00,204 - WARNING - 해당 시간대(2025-05-15 11:14:00-04:00 ~ 2025-05-15 11:15:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:15:01,391 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:15:01,391 - INFO - 다음 데이터 수집 시간(00:16:00)까지 58.6초 대기...
# 2025-05-16 00:16:00,004 - INFO - === 11:16에 11:15의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:16:00,006 - INFO - 요청 시간 범위: 2025-05-15 11:15:00-04:00 ~ 2025-05-15 11:16:00-04:00 (뉴욕 시간)
# 2025-05-16 00:16:00,215 - WARNING - 해당 시간대(2025-05-15 11:15:00-04:00 ~ 2025-05-15 11:16:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:16:01,402 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:16:01,404 - INFO - 다음 데이터 수집 시간(00:17:00)까지 58.6초 대기...
# 2025-05-16 00:17:00,010 - INFO - === 11:17에 11:16의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:17:00,011 - INFO - 요청 시간 범위: 2025-05-15 11:16:00-04:00 ~ 2025-05-15 11:17:00-04:00 (뉴욕 시간)
# 2025-05-16 00:17:00,214 - WARNING - 해당 시간대(2025-05-15 11:16:00-04:00 ~ 2025-05-15 11:17:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:17:01,409 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:17:01,410 - INFO - 다음 데이터 수집 시간(00:18:00)까지 58.6초 대기...
# 2025-05-16 00:18:00,007 - INFO - === 11:18에 11:17의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:18:00,008 - INFO - 요청 시간 범위: 2025-05-15 11:17:00-04:00 ~ 2025-05-15 11:18:00-04:00 (뉴욕 시간)
# 2025-05-16 00:18:00,207 - WARNING - 해당 시간대(2025-05-15 11:17:00-04:00 ~ 2025-05-15 11:18:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:18:01,391 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:18:01,392 - INFO - 다음 데이터 수집 시간(00:19:00)까지 58.6초 대기...
# 2025-05-16 00:19:00,001 - INFO - === 11:19에 11:18의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:19:00,003 - INFO - 요청 시간 범위: 2025-05-15 11:18:00-04:00 ~ 2025-05-15 11:19:00-04:00 (뉴욕 시간)
# 2025-05-16 00:19:00,208 - WARNING - 해당 시간대(2025-05-15 11:18:00-04:00 ~ 2025-05-15 11:19:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:19:01,402 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:19:01,404 - INFO - 다음 데이터 수집 시간(00:20:00)까지 58.6초 대기...
# 2025-05-16 00:20:00,005 - INFO - === 11:20에 11:19의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:20:00,006 - INFO - 요청 시간 범위: 2025-05-15 11:19:00-04:00 ~ 2025-05-15 11:20:00-04:00 (뉴욕 시간)
# 2025-05-16 00:20:00,213 - WARNING - 해당 시간대(2025-05-15 11:19:00-04:00 ~ 2025-05-15 11:20:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:20:01,393 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:20:01,394 - INFO - 다음 데이터 수집 시간(00:21:00)까지 58.6초 대기...
# 2025-05-16 00:21:00,008 - INFO - === 11:21에 11:20의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:21:00,009 - INFO - 요청 시간 범위: 2025-05-15 11:20:00-04:00 ~ 2025-05-15 11:21:00-04:00 (뉴욕 시간)
# 2025-05-16 00:21:00,213 - WARNING - 해당 시간대(2025-05-15 11:20:00-04:00 ~ 2025-05-15 11:21:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:21:01,404 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:21:01,406 - INFO - 다음 데이터 수집 시간(00:22:00)까지 58.6초 대기...
# 2025-05-16 00:22:00,008 - INFO - === 11:22에 11:21의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:22:00,009 - INFO - 요청 시간 범위: 2025-05-15 11:21:00-04:00 ~ 2025-05-15 11:22:00-04:00 (뉴욕 시간)
# 2025-05-16 00:22:00,214 - WARNING - 해당 시간대(2025-05-15 11:21:00-04:00 ~ 2025-05-15 11:22:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:22:01,397 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:22:01,397 - INFO - 다음 데이터 수집 시간(00:23:00)까지 58.6초 대기...
# 2025-05-16 00:23:00,017 - INFO - === 11:23에 11:22의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:23:00,018 - INFO - 요청 시간 범위: 2025-05-15 11:22:00-04:00 ~ 2025-05-15 11:23:00-04:00 (뉴욕 시간)
# 2025-05-16 00:23:00,217 - WARNING - 해당 시간대(2025-05-15 11:22:00-04:00 ~ 2025-05-15 11:23:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:23:01,403 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:23:01,404 - INFO - 다음 데이터 수집 시간(00:24:00)까지 58.6초 대기...
# 2025-05-16 00:24:00,011 - INFO - === 11:24에 11:23의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:24:00,012 - INFO - 요청 시간 범위: 2025-05-15 11:23:00-04:00 ~ 2025-05-15 11:24:00-04:00 (뉴욕 시간)
# 2025-05-16 00:24:00,227 - WARNING - 해당 시간대(2025-05-15 11:23:00-04:00 ~ 2025-05-15 11:24:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:24:01,417 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:24:01,418 - INFO - 다음 데이터 수집 시간(00:25:00)까지 58.6초 대기...
# 2025-05-16 00:25:00,001 - INFO - === 11:25에 11:24의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:25:00,003 - INFO - 요청 시간 범위: 2025-05-15 11:24:00-04:00 ~ 2025-05-15 11:25:00-04:00 (뉴욕 시간)
# 2025-05-16 00:25:00,207 - WARNING - 해당 시간대(2025-05-15 11:24:00-04:00 ~ 2025-05-15 11:25:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:25:02,043 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:25:02,044 - INFO - 다음 데이터 수집 시간(00:26:00)까지 58.0초 대기...
# 2025-05-16 00:26:00,009 - INFO - === 11:26에 11:25의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:26:00,010 - INFO - 요청 시간 범위: 2025-05-15 11:25:00-04:00 ~ 2025-05-15 11:26:00-04:00 (뉴욕 시간)
# 2025-05-16 00:26:00,876 - WARNING - VALE에 대한 데이터가 없습니다.
# 2025-05-16 00:26:00,878 - WARNING - NFLX에 대한 데이터가 없습니다.
# 2025-05-16 00:26:00,882 - WARNING - PBR에 대한 데이터가 없습니다.
# 2025-05-16 00:26:00,884 - WARNING - SHEL에 대한 데이터가 없습니다.
# 2025-05-16 00:26:00,887 - WARNING - AZN에 대한 데이터가 없습니다.
# 2025-05-16 00:26:00,890 - WARNING - RTX에 대한 데이터가 없습니다.
# 2025-05-16 00:26:00,892 - WARNING - YMM에 대한 데이터가 없습니다.
# 2025-05-16 00:26:00,894 - INFO - 총 22개 종목의 1분봉 데이터를 성공적으로 가져왔습니다.
# 2025-05-16 00:26:00,895 - INFO - 현재 시간 (뉴욕): 2025-05-15 11:26:00.895713-04:00
# 2025-05-16 00:26:00,896 - INFO - ============================================================
# 2025-05-16 00:26:00,897 - INFO - AAPL  - 시간: 2025-05-15 15:25:00+00:00, 시가: $212.63, 고가: $212.65, 저가: $212.38, 종가: $212.40, 거래량: 2853.0
# 2025-05-16 00:26:00,898 - INFO - ABT   - 시간: 2025-05-15 15:25:00+00:00, 시가: $132.33, 고가: $132.35, 저가: $132.28, 종가: $132.35, 거래량: 1429.0
# 2025-05-16 00:26:00,899 - INFO - AMZN  - 시간: 2025-05-15 15:25:00+00:00, 시가: $203.39, 고가: $203.42, 저가: $202.75, 종가: $203.28, 거래량: 13279.0
# 2025-05-16 00:26:00,900 - INFO - AZN   - 시간: 2025-05-15 14:23:00+00:00, 시가: $67.20, 고가: $67.20, 저가: $67.13, 종가: $67.13, 거래량: 862.0
# 2025-05-16 00:26:00,901 - INFO - BA    - 시간: 2025-05-15 15:25:00+00:00, 시가: $207.72, 고가: $207.74, 저가: $207.62, 종가: $207.71, 거래량: 1805.0
# 2025-05-16 00:26:00,902 - INFO - CSX   - 시간: 2025-05-15 15:25:00+00:00, 시가: $31.19, 고가: $31.20, 저가: $31.19, 종가: $31.19, 거래량: 895.0
# 2025-05-16 00:26:00,903 - INFO - ERIC  - 시간: 2025-05-15 15:25:00+00:00, 시가: $8.48, 고가: $8.48, 저가: $8.48, 종가: $8.48, 거래량: 23858.0
# 2025-05-16 00:26:00,904 - INFO - FCX   - 시간: 2025-05-15 15:25:00+00:00, 시가: $38.05, 고가: $38.08, 저가: $38.04, 종가: $38.08, 거래량: 2062.0
# 2025-05-16 00:26:00,905 - INFO - ITUB  - 시간: 2025-05-15 15:25:00+00:00, 시가: $6.67, 고가: $6.67, 저가: $6.67, 종가: $6.67, 거래량: 1200.0
# 2025-05-16 00:26:00,906 - INFO - KMI   - 시간: 2025-05-15 15:25:00+00:00, 시가: $27.89, 고가: $27.89, 저가: $27.88, 종가: $27.88, 거래량: 710.0
# 2025-05-16 00:26:00,907 - INFO - KVUE  - 시간: 2025-05-15 15:25:00+00:00, 시가: $23.73, 고가: $23.75, 저가: $23.73, 종가: $23.75, 거래량: 1177.0
# 2025-05-16 00:26:00,908 - INFO - MUFG  - 시간: 2025-05-15 15:25:00+00:00, 시가: $13.36, 고가: $13.37, 저가: $13.36, 종가: $13.36, 거래량: 5400.0
# 2025-05-16 00:26:00,909 - INFO - NEE   - 시간: 2025-05-15 15:25:00+00:00, 시가: $73.85, 고가: $73.86, 저가: $73.82, 종가: $73.83, 거래량: 2404.0
# 2025-05-16 00:26:00,909 - INFO - NEM   - 시간: 2025-05-15 15:25:00+00:00, 시가: $49.00, 고가: $49.03, 저가: $49.00, 종가: $49.03, 거래량: 805.0
# 2025-05-16 00:26:00,910 - INFO - NFLX  - 데이터 없음
# 2025-05-16 00:26:00,911 - INFO - NKE   - 시간: 2025-05-15 15:25:00+00:00, 시가: $62.33, 고가: $62.34, 저가: $62.33, 종가: $62.33, 거래량: 590.0
# 2025-05-16 00:26:00,911 - INFO - NVDA  - 시간: 2025-05-15 15:25:00+00:00, 시가: $134.17, 고가: $134.17, 저가: $134.00, 종가: $134.10, 거래량: 4627.0
# 2025-05-16 00:26:00,912 - INFO - PBR   - 데이터 없음
# 2025-05-16 00:26:00,913 - INFO - PEP   - 시간: 2025-05-15 15:25:00+00:00, 시가: $130.69, 고가: $130.69, 저가: $130.68, 종가: $130.68, 거래량: 378.0
# 2025-05-16 00:26:00,914 - INFO - PM    - 시간: 2025-05-15 15:25:00+00:00, 시가: $168.22, 고가: $168.22, 저가: $168.21, 종가: $168.21, 거래량: 216.0
# 2025-05-16 00:26:00,915 - INFO - RTX   - 시간: 2025-05-15 14:23:00+00:00, 시가: $133.00, 고가: $133.10, 저가: $132.97, 종가: $133.10, 거래량: 1416.0
# 2025-05-16 00:26:00,915 - INFO - SHEL  - 데이터 없음
# 2025-05-16 00:26:00,916 - INFO - T     - 시간: 2025-05-15 15:25:00+00:00, 시가: $27.23, 고가: $27.25, 저가: $27.23, 종가: $27.25, 거래량: 6670.0
# 2025-05-16 00:26:00,916 - INFO - TSLA  - 시간: 2025-05-15 15:25:00+00:00, 시가: $338.89, 고가: $338.89, 저가: $338.57, 종가: $338.64, 거래량: 676.0
# 2025-05-16 00:26:00,917 - INFO - UNH   - 시간: 2025-05-15 15:25:00+00:00, 시가: $262.50, 고가: $262.50, 저가: $261.50, 종가: $261.50, 거래량: 6076.0
# 2025-05-16 00:26:00,917 - INFO - USB   - 시간: 2025-05-15 15:25:00+00:00, 시가: $44.40, 고가: $44.40, 저가: $44.40, 종가: $44.40, 거래량: 211.0
# 2025-05-16 00:26:00,918 - INFO - VALE  - 데이터 없음
# 2025-05-16 00:26:00,919 - INFO - WBD   - 시간: 2025-05-15 15:25:00+00:00, 시가: $9.13, 고가: $9.13, 저가: $9.13, 종가: $9.13, 거래량: 239.0
# 2025-05-16 00:26:00,920 - INFO - YMM   - 시간: 2025-05-15 14:23:00+00:00, 시가: $12.48, 고가: $12.49, 저가: $12.48, 종가: $12.49, 거래량: 200.0
# 2025-05-16 00:26:00,921 - INFO - ============================================================
# 2025-05-16 00:26:00,929 - INFO - 데이터가 stock_data_20250515_1126.csv에 저장되었습니다.
# 2025-05-16 00:26:02,122 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:26:02,123 - INFO - 다음 데이터 수집 시간(00:27:00)까지 57.9초 대기...
# 2025-05-16 00:27:00,008 - INFO - === 11:27에 11:26의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:27:00,010 - INFO - 요청 시간 범위: 2025-05-15 11:26:00-04:00 ~ 2025-05-15 11:27:00-04:00 (뉴욕 시간)
# 2025-05-16 00:27:00,208 - WARNING - 해당 시간대(2025-05-15 11:26:00-04:00 ~ 2025-05-15 11:27:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:27:01,391 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:27:01,392 - INFO - 다음 데이터 수집 시간(00:28:00)까지 58.6초 대기...
# 2025-05-16 00:28:00,015 - INFO - === 11:28에 11:27의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:28:00,016 - INFO - 요청 시간 범위: 2025-05-15 11:27:00-04:00 ~ 2025-05-15 11:28:00-04:00 (뉴욕 시간)
# 2025-05-16 00:28:00,226 - WARNING - 해당 시간대(2025-05-15 11:27:00-04:00 ~ 2025-05-15 11:28:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:28:01,419 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:28:01,419 - INFO - 다음 데이터 수집 시간(00:29:00)까지 58.6초 대기...
# 2025-05-16 00:29:00,016 - INFO - === 11:29에 11:28의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:29:00,016 - INFO - 요청 시간 범위: 2025-05-15 11:28:00-04:00 ~ 2025-05-15 11:29:00-04:00 (뉴욕 시간)
# 2025-05-16 00:29:00,213 - WARNING - 해당 시간대(2025-05-15 11:28:00-04:00 ~ 2025-05-15 11:29:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:29:01,404 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:29:01,405 - INFO - 다음 데이터 수집 시간(00:30:00)까지 58.6초 대기...
# 2025-05-16 00:30:00,002 - INFO - === 11:30에 11:29의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:30:00,003 - INFO - 요청 시간 범위: 2025-05-15 11:29:00-04:00 ~ 2025-05-15 11:30:00-04:00 (뉴욕 시간)
# 2025-05-16 00:30:00,201 - WARNING - 해당 시간대(2025-05-15 11:29:00-04:00 ~ 2025-05-15 11:30:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:30:01,387 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:30:01,388 - INFO - 다음 데이터 수집 시간(00:31:00)까지 58.6초 대기...
# 2025-05-16 00:31:00,006 - INFO - === 11:31에 11:30의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:31:00,008 - INFO - 요청 시간 범위: 2025-05-15 11:30:00-04:00 ~ 2025-05-15 11:31:00-04:00 (뉴욕 시간)
# 2025-05-16 00:31:00,208 - WARNING - 해당 시간대(2025-05-15 11:30:00-04:00 ~ 2025-05-15 11:31:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:31:01,399 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:31:01,400 - INFO - 다음 데이터 수집 시간(00:32:00)까지 58.6초 대기...
# 2025-05-16 00:32:00,007 - INFO - === 11:32에 11:31의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:32:00,009 - INFO - 요청 시간 범위: 2025-05-15 11:31:00-04:00 ~ 2025-05-15 11:32:00-04:00 (뉴욕 시간)
# 2025-05-16 00:32:00,211 - WARNING - 해당 시간대(2025-05-15 11:31:00-04:00 ~ 2025-05-15 11:32:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:32:01,400 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:32:01,400 - INFO - 다음 데이터 수집 시간(00:33:00)까지 58.6초 대기...
# 2025-05-16 00:33:00,010 - INFO - === 11:33에 11:32의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:33:00,011 - INFO - 요청 시간 범위: 2025-05-15 11:32:00-04:00 ~ 2025-05-15 11:33:00-04:00 (뉴욕 시간)
# 2025-05-16 00:33:00,215 - WARNING - 해당 시간대(2025-05-15 11:32:00-04:00 ~ 2025-05-15 11:33:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:33:01,401 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:33:01,402 - INFO - 다음 데이터 수집 시간(00:34:00)까지 58.6초 대기...
# 2025-05-16 00:34:00,016 - INFO - === 11:34에 11:33의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:34:00,016 - INFO - 요청 시간 범위: 2025-05-15 11:33:00-04:00 ~ 2025-05-15 11:34:00-04:00 (뉴욕 시간)
# 2025-05-16 00:34:00,215 - WARNING - 해당 시간대(2025-05-15 11:33:00-04:00 ~ 2025-05-15 11:34:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:34:01,397 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:34:01,398 - INFO - 다음 데이터 수집 시간(00:35:00)까지 58.6초 대기...
# 2025-05-16 00:35:00,008 - INFO - === 11:35에 11:34의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:35:00,009 - INFO - 요청 시간 범위: 2025-05-15 11:34:00-04:00 ~ 2025-05-15 11:35:00-04:00 (뉴욕 시간)
# 2025-05-16 00:35:00,206 - WARNING - 해당 시간대(2025-05-15 11:34:00-04:00 ~ 2025-05-15 11:35:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:35:01,392 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:35:01,394 - INFO - 다음 데이터 수집 시간(00:36:00)까지 58.6초 대기...
# 2025-05-16 00:36:00,012 - INFO - === 11:36에 11:35의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:36:00,014 - INFO - 요청 시간 범위: 2025-05-15 11:35:00-04:00 ~ 2025-05-15 11:36:00-04:00 (뉴욕 시간)
# 2025-05-16 00:36:00,211 - WARNING - 해당 시간대(2025-05-15 11:35:00-04:00 ~ 2025-05-15 11:36:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:36:01,400 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:36:01,401 - INFO - 다음 데이터 수집 시간(00:37:00)까지 58.6초 대기...
# 2025-05-16 00:37:00,008 - INFO - === 11:37에 11:36의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:37:00,009 - INFO - 요청 시간 범위: 2025-05-15 11:36:00-04:00 ~ 2025-05-15 11:37:00-04:00 (뉴욕 시간)
# 2025-05-16 00:37:00,207 - WARNING - 해당 시간대(2025-05-15 11:36:00-04:00 ~ 2025-05-15 11:37:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:37:01,393 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:37:01,394 - INFO - 다음 데이터 수집 시간(00:38:00)까지 58.6초 대기...
# 2025-05-16 00:38:00,010 - INFO - === 11:38에 11:37의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:38:00,013 - INFO - 요청 시간 범위: 2025-05-15 11:37:00-04:00 ~ 2025-05-15 11:38:00-04:00 (뉴욕 시간)
# 2025-05-16 00:38:00,212 - WARNING - 해당 시간대(2025-05-15 11:37:00-04:00 ~ 2025-05-15 11:38:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:38:01,405 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:38:01,406 - INFO - 다음 데이터 수집 시간(00:39:00)까지 58.6초 대기...
# 2025-05-16 00:39:00,011 - INFO - === 11:39에 11:38의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:39:00,014 - INFO - 요청 시간 범위: 2025-05-15 11:38:00-04:00 ~ 2025-05-15 11:39:00-04:00 (뉴욕 시간)
# 2025-05-16 00:39:00,210 - WARNING - 해당 시간대(2025-05-15 11:38:00-04:00 ~ 2025-05-15 11:39:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:39:01,406 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:39:01,407 - INFO - 다음 데이터 수집 시간(00:40:00)까지 58.6초 대기...
# 2025-05-16 00:40:00,006 - INFO - === 11:40에 11:39의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:40:00,007 - INFO - 요청 시간 범위: 2025-05-15 11:39:00-04:00 ~ 2025-05-15 11:40:00-04:00 (뉴욕 시간)
# 2025-05-16 00:40:00,208 - WARNING - 해당 시간대(2025-05-15 11:39:00-04:00 ~ 2025-05-15 11:40:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:40:01,394 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:40:01,395 - INFO - 다음 데이터 수집 시간(00:41:00)까지 58.6초 대기...
# 2025-05-16 00:41:00,017 - INFO - === 11:41에 11:40의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:41:00,018 - INFO - 요청 시간 범위: 2025-05-15 11:40:00-04:00 ~ 2025-05-15 11:41:00-04:00 (뉴욕 시간)
# 2025-05-16 00:41:00,214 - WARNING - 해당 시간대(2025-05-15 11:40:00-04:00 ~ 2025-05-15 11:41:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:41:01,406 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:41:01,407 - INFO - 다음 데이터 수집 시간(00:42:00)까지 58.6초 대기...
# 2025-05-16 00:42:00,009 - INFO - === 11:42에 11:41의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:42:00,010 - INFO - 요청 시간 범위: 2025-05-15 11:41:00-04:00 ~ 2025-05-15 11:42:00-04:00 (뉴욕 시간)
# 2025-05-16 00:42:00,208 - WARNING - 해당 시간대(2025-05-15 11:41:00-04:00 ~ 2025-05-15 11:42:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:42:01,394 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:42:01,395 - INFO - 다음 데이터 수집 시간(00:43:00)까지 58.6초 대기...
# 2025-05-16 00:43:00,003 - INFO - === 11:43에 11:42의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:43:00,004 - INFO - 요청 시간 범위: 2025-05-15 11:42:00-04:00 ~ 2025-05-15 11:43:00-04:00 (뉴욕 시간)
# 2025-05-16 00:43:00,198 - WARNING - 해당 시간대(2025-05-15 11:42:00-04:00 ~ 2025-05-15 11:43:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:43:01,394 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:43:01,395 - INFO - 다음 데이터 수집 시간(00:44:00)까지 58.6초 대기...
# 2025-05-16 00:44:00,012 - INFO - === 11:44에 11:43의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:44:00,013 - INFO - 요청 시간 범위: 2025-05-15 11:43:00-04:00 ~ 2025-05-15 11:44:00-04:00 (뉴욕 시간)
# 2025-05-16 00:44:00,211 - WARNING - 해당 시간대(2025-05-15 11:43:00-04:00 ~ 2025-05-15 11:44:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:44:01,405 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:44:01,406 - INFO - 다음 데이터 수집 시간(00:45:00)까지 58.6초 대기...
# 2025-05-16 00:45:00,014 - INFO - === 11:45에 11:44의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:45:00,015 - INFO - 요청 시간 범위: 2025-05-15 11:44:00-04:00 ~ 2025-05-15 11:45:00-04:00 (뉴욕 시간)
# 2025-05-16 00:45:00,235 - WARNING - 해당 시간대(2025-05-15 11:44:00-04:00 ~ 2025-05-15 11:45:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:45:01,420 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:45:01,421 - INFO - 다음 데이터 수집 시간(00:46:00)까지 58.6초 대기...
# 2025-05-16 00:46:00,014 - INFO - === 11:46에 11:45의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:46:00,015 - INFO - 요청 시간 범위: 2025-05-15 11:45:00-04:00 ~ 2025-05-15 11:46:00-04:00 (뉴욕 시간)
# 2025-05-16 00:46:00,217 - WARNING - 해당 시간대(2025-05-15 11:45:00-04:00 ~ 2025-05-15 11:46:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:46:01,404 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:46:01,405 - INFO - 다음 데이터 수집 시간(00:47:00)까지 58.6초 대기...
# 2025-05-16 00:47:00,000 - INFO - === 11:47에 11:46의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:47:00,001 - INFO - 요청 시간 범위: 2025-05-15 11:46:00-04:00 ~ 2025-05-15 11:47:00-04:00 (뉴욕 시간)
# 2025-05-16 00:47:00,201 - WARNING - 해당 시간대(2025-05-15 11:46:00-04:00 ~ 2025-05-15 11:47:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:47:01,397 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:47:01,398 - INFO - 다음 데이터 수집 시간(00:48:00)까지 58.6초 대기...
# 2025-05-16 00:48:00,007 - INFO - === 11:48에 11:47의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:48:00,008 - INFO - 요청 시간 범위: 2025-05-15 11:47:00-04:00 ~ 2025-05-15 11:48:00-04:00 (뉴욕 시간)
# 2025-05-16 00:48:00,204 - WARNING - 해당 시간대(2025-05-15 11:47:00-04:00 ~ 2025-05-15 11:48:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:48:01,399 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:48:01,400 - INFO - 다음 데이터 수집 시간(00:49:00)까지 58.6초 대기...
# 2025-05-16 00:49:00,012 - INFO - === 11:49에 11:48의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:49:00,013 - INFO - 요청 시간 범위: 2025-05-15 11:48:00-04:00 ~ 2025-05-15 11:49:00-04:00 (뉴욕 시간)
# 2025-05-16 00:49:00,212 - WARNING - 해당 시간대(2025-05-15 11:48:00-04:00 ~ 2025-05-15 11:49:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:49:01,402 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:49:01,403 - INFO - 다음 데이터 수집 시간(00:50:00)까지 58.6초 대기...
# 2025-05-16 00:50:00,016 - INFO - === 11:50에 11:49의 1분봉 데이터 수집 중... ===
# 2025-05-16 00:50:00,017 - INFO - 요청 시간 범위: 2025-05-15 11:49:00-04:00 ~ 2025-05-15 11:50:00-04:00 (뉴욕 시간)
# 2025-05-16 00:50:00,213 - WARNING - 해당 시간대(2025-05-15 11:49:00-04:00 ~ 2025-05-15 11:50:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 00:50:01,409 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 00:50:01,410 - INFO - 다음 데이터 수집 시간(00:51:00)까지 58.6초 대기...
# 2025-05-16 00:51:00,015 - INFO - === 11:51에 11:50의 1분봉 데이터 수집 중... ===
# ...
# 2025-05-16 04:34:00,982 - INFO - SHEL  - 시간: 2025-05-15 19:33:00+00:00, 시가: $67.32, 고가: $67.32, 저가: $67.32, 종가: $67.32, 거래량: 164.0
# 2025-05-16 04:34:00,983 - INFO - T     - 시간: 2025-05-15 19:33:00+00:00, 시가: $27.37, 고가: $27.38, 저가: $27.37, 종가: $27.37, 거래량: 3878.0
# 2025-05-16 04:34:00,983 - INFO - TSLA  - 시간: 2025-05-15 19:33:00+00:00, 시가: $340.82, 고가: $341.24, 저가: $340.82, 종가: $341.17, 거래량: 1058.0
# 2025-05-16 04:34:00,984 - INFO - UNH   - 시간: 2025-05-15 19:33:00+00:00, 시가: $270.93, 고가: $271.89, 저가: $270.88, 종가: $271.86, 거래량: 6445.0
# 2025-05-16 04:34:00,985 - INFO - USB   - 시간: 2025-05-15 19:33:00+00:00, 시가: $44.64, 고가: $44.65, 저가: $44.64, 종가: $44.64, 거래량: 703.0
# 2025-05-16 04:34:00,985 - INFO - VALE  - 시간: 2025-05-15 18:31:00+00:00, 시가: $9.78, 고가: $9.78, 저가: $9.78, 종가: $9.78, 거래량: 300.0
# 2025-05-16 04:34:00,986 - INFO - WBD   - 시간: 2025-05-15 19:33:00+00:00, 시가: $9.19, 고가: $9.19, 저가: $9.18, 종가: $9.18, 거래량: 27853.0
# 2025-05-16 04:34:00,986 - INFO - YMM   - 시간: 2025-05-15 18:31:00+00:00, 시가: $12.49, 고가: $12.49, 저가: $12.49, 종가: $12.49, 거래량: 100.0
# 2025-05-16 04:34:00,987 - INFO - ============================================================
# 2025-05-16 04:34:00,993 - INFO - 데이터가 stock_data_20250515_1534.csv에 저장되었습니다.
# 2025-05-16 04:34:02,194 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:34:02,195 - INFO - 다음 데이터 수집 시간(04:35:00)까지 57.8초 대기...
# 2025-05-16 04:35:00,012 - INFO - === 15:35에 15:34의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:35:00,013 - INFO - 요청 시간 범위: 2025-05-15 15:34:00-04:00 ~ 2025-05-15 15:35:00-04:00 (뉴욕 시간)
# 2025-05-16 04:35:00,228 - WARNING - 해당 시간대(2025-05-15 15:34:00-04:00 ~ 2025-05-15 15:35:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:35:01,431 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:35:01,432 - INFO - 다음 데이터 수집 시간(04:36:00)까지 58.6초 대기...
# 2025-05-16 04:36:00,014 - INFO - === 15:36에 15:35의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:36:00,015 - INFO - 요청 시간 범위: 2025-05-15 15:35:00-04:00 ~ 2025-05-15 15:36:00-04:00 (뉴욕 시간)
# 2025-05-16 04:36:00,236 - WARNING - 해당 시간대(2025-05-15 15:35:00-04:00 ~ 2025-05-15 15:36:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:36:01,487 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:36:01,489 - INFO - 다음 데이터 수집 시간(04:37:00)까지 58.5초 대기...
# 2025-05-16 04:37:00,014 - INFO - === 15:37에 15:36의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:37:00,015 - INFO - 요청 시간 범위: 2025-05-15 15:36:00-04:00 ~ 2025-05-15 15:37:00-04:00 (뉴욕 시간)
# 2025-05-16 04:37:00,228 - WARNING - 해당 시간대(2025-05-15 15:36:00-04:00 ~ 2025-05-15 15:37:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:37:01,434 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:37:01,435 - INFO - 다음 데이터 수집 시간(04:38:00)까지 58.6초 대기...
# 2025-05-16 04:38:00,006 - INFO - === 15:38에 15:37의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:38:00,007 - INFO - 요청 시간 범위: 2025-05-15 15:37:00-04:00 ~ 2025-05-15 15:38:00-04:00 (뉴욕 시간)
# 2025-05-16 04:38:00,224 - WARNING - 해당 시간대(2025-05-15 15:37:00-04:00 ~ 2025-05-15 15:38:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:38:01,425 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:38:01,426 - INFO - 다음 데이터 수집 시간(04:39:00)까지 58.6초 대기...
# 2025-05-16 04:39:00,003 - INFO - === 15:39에 15:38의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:39:00,004 - INFO - 요청 시간 범위: 2025-05-15 15:38:00-04:00 ~ 2025-05-15 15:39:00-04:00 (뉴욕 시간)
# 2025-05-16 04:39:00,223 - WARNING - 해당 시간대(2025-05-15 15:38:00-04:00 ~ 2025-05-15 15:39:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:39:01,428 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:39:01,429 - INFO - 다음 데이터 수집 시간(04:40:00)까지 58.6초 대기...
# 2025-05-16 04:40:00,003 - INFO - === 15:40에 15:39의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:40:00,004 - INFO - 요청 시간 범위: 2025-05-15 15:39:00-04:00 ~ 2025-05-15 15:40:00-04:00 (뉴욕 시간)
# 2025-05-16 04:40:00,222 - WARNING - 해당 시간대(2025-05-15 15:39:00-04:00 ~ 2025-05-15 15:40:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:40:01,426 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:40:01,428 - INFO - 다음 데이터 수집 시간(04:41:00)까지 58.6초 대기...
# 2025-05-16 04:41:00,010 - INFO - === 15:41에 15:40의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:41:00,011 - INFO - 요청 시간 범위: 2025-05-15 15:40:00-04:00 ~ 2025-05-15 15:41:00-04:00 (뉴욕 시간)
# 2025-05-16 04:41:00,227 - WARNING - 해당 시간대(2025-05-15 15:40:00-04:00 ~ 2025-05-15 15:41:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:41:01,433 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:41:01,434 - INFO - 다음 데이터 수집 시간(04:42:00)까지 58.6초 대기...
# 2025-05-16 04:42:00,004 - INFO - === 15:42에 15:41의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:42:00,006 - INFO - 요청 시간 범위: 2025-05-15 15:41:00-04:00 ~ 2025-05-15 15:42:00-04:00 (뉴욕 시간)
# 2025-05-16 04:42:00,226 - WARNING - 해당 시간대(2025-05-15 15:41:00-04:00 ~ 2025-05-15 15:42:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:42:01,440 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:42:01,441 - INFO - 다음 데이터 수집 시간(04:43:00)까지 58.6초 대기...
# 2025-05-16 04:43:00,003 - INFO - === 15:43에 15:42의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:43:00,005 - INFO - 요청 시간 범위: 2025-05-15 15:42:00-04:00 ~ 2025-05-15 15:43:00-04:00 (뉴욕 시간)
# 2025-05-16 04:43:00,222 - WARNING - 해당 시간대(2025-05-15 15:42:00-04:00 ~ 2025-05-15 15:43:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:43:01,428 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:43:01,429 - INFO - 다음 데이터 수집 시간(04:44:00)까지 58.6초 대기...
# 2025-05-16 04:44:00,003 - INFO - === 15:44에 15:43의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:44:00,004 - INFO - 요청 시간 범위: 2025-05-15 15:43:00-04:00 ~ 2025-05-15 15:44:00-04:00 (뉴욕 시간)
# 2025-05-16 04:44:00,223 - WARNING - 해당 시간대(2025-05-15 15:43:00-04:00 ~ 2025-05-15 15:44:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:44:01,437 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:44:01,438 - INFO - 다음 데이터 수집 시간(04:45:00)까지 58.6초 대기...
# 2025-05-16 04:45:00,006 - INFO - === 15:45에 15:44의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:45:00,008 - INFO - 요청 시간 범위: 2025-05-15 15:44:00-04:00 ~ 2025-05-15 15:45:00-04:00 (뉴욕 시간)
# 2025-05-16 04:45:00,225 - WARNING - 해당 시간대(2025-05-15 15:44:00-04:00 ~ 2025-05-15 15:45:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:45:01,441 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:45:01,442 - INFO - 다음 데이터 수집 시간(04:46:00)까지 58.6초 대기...
# 2025-05-16 04:46:00,015 - INFO - === 15:46에 15:45의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:46:00,016 - INFO - 요청 시간 범위: 2025-05-15 15:45:00-04:00 ~ 2025-05-15 15:46:00-04:00 (뉴욕 시간)
# 2025-05-16 04:46:00,232 - WARNING - 해당 시간대(2025-05-15 15:45:00-04:00 ~ 2025-05-15 15:46:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:46:01,442 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:46:01,443 - INFO - 다음 데이터 수집 시간(04:47:00)까지 58.6초 대기...
# 2025-05-16 04:47:00,009 - INFO - === 15:47에 15:46의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:47:00,010 - INFO - 요청 시간 범위: 2025-05-15 15:46:00-04:00 ~ 2025-05-15 15:47:00-04:00 (뉴욕 시간)
# 2025-05-16 04:47:00,226 - WARNING - 해당 시간대(2025-05-15 15:46:00-04:00 ~ 2025-05-15 15:47:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:47:01,427 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:47:01,428 - INFO - 다음 데이터 수집 시간(04:48:00)까지 58.6초 대기...
# 2025-05-16 04:48:00,017 - INFO - === 15:48에 15:47의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:48:00,017 - INFO - 요청 시간 범위: 2025-05-15 15:47:00-04:00 ~ 2025-05-15 15:48:00-04:00 (뉴욕 시간)
# 2025-05-16 04:48:00,233 - WARNING - 해당 시간대(2025-05-15 15:47:00-04:00 ~ 2025-05-15 15:48:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:48:01,441 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:48:01,442 - INFO - 다음 데이터 수집 시간(04:49:00)까지 58.6초 대기...
# 2025-05-16 04:49:00,007 - INFO - === 15:49에 15:48의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:49:00,008 - INFO - 요청 시간 범위: 2025-05-15 15:48:00-04:00 ~ 2025-05-15 15:49:00-04:00 (뉴욕 시간)
# 2025-05-16 04:49:00,231 - WARNING - 해당 시간대(2025-05-15 15:48:00-04:00 ~ 2025-05-15 15:49:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:49:01,446 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:49:01,447 - INFO - 다음 데이터 수집 시간(04:50:00)까지 58.6초 대기...
# 2025-05-16 04:50:00,005 - INFO - === 15:50에 15:49의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:50:00,006 - INFO - 요청 시간 범위: 2025-05-15 15:49:00-04:00 ~ 2025-05-15 15:50:00-04:00 (뉴욕 시간)
# 2025-05-16 04:50:00,227 - WARNING - 해당 시간대(2025-05-15 15:49:00-04:00 ~ 2025-05-15 15:50:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:50:01,440 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:50:01,441 - INFO - 다음 데이터 수집 시간(04:51:00)까지 58.6초 대기...
# 2025-05-16 04:51:00,010 - INFO - === 15:51에 15:50의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:51:00,012 - INFO - 요청 시간 범위: 2025-05-15 15:50:00-04:00 ~ 2025-05-15 15:51:00-04:00 (뉴욕 시간)
# 2025-05-16 04:51:00,229 - WARNING - 해당 시간대(2025-05-15 15:50:00-04:00 ~ 2025-05-15 15:51:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:51:01,436 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:51:01,437 - INFO - 다음 데이터 수집 시간(04:52:00)까지 58.6초 대기...
# 2025-05-16 04:52:00,006 - INFO - === 15:52에 15:51의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:52:00,007 - INFO - 요청 시간 범위: 2025-05-15 15:51:00-04:00 ~ 2025-05-15 15:52:00-04:00 (뉴욕 시간)
# 2025-05-16 04:52:00,227 - WARNING - 해당 시간대(2025-05-15 15:51:00-04:00 ~ 2025-05-15 15:52:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:52:01,442 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:52:01,443 - INFO - 다음 데이터 수집 시간(04:53:00)까지 58.6초 대기...
# 2025-05-16 04:53:00,016 - INFO - === 15:53에 15:52의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:53:00,017 - INFO - 요청 시간 범위: 2025-05-15 15:52:00-04:00 ~ 2025-05-15 15:53:00-04:00 (뉴욕 시간)
# 2025-05-16 04:53:00,243 - WARNING - 해당 시간대(2025-05-15 15:52:00-04:00 ~ 2025-05-15 15:53:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:53:01,455 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:53:01,456 - INFO - 다음 데이터 수집 시간(04:54:00)까지 58.5초 대기...
# 2025-05-16 04:54:00,004 - INFO - === 15:54에 15:53의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:54:00,006 - INFO - 요청 시간 범위: 2025-05-15 15:53:00-04:00 ~ 2025-05-15 15:54:00-04:00 (뉴욕 시간)
# 2025-05-16 04:54:00,221 - WARNING - 해당 시간대(2025-05-15 15:53:00-04:00 ~ 2025-05-15 15:54:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:54:01,429 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:54:01,430 - INFO - 다음 데이터 수집 시간(04:55:00)까지 58.6초 대기...
# 2025-05-16 04:55:00,018 - INFO - === 15:55에 15:54의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:55:00,019 - INFO - 요청 시간 범위: 2025-05-15 15:54:00-04:00 ~ 2025-05-15 15:55:00-04:00 (뉴욕 시간)
# 2025-05-16 04:55:00,234 - WARNING - 해당 시간대(2025-05-15 15:54:00-04:00 ~ 2025-05-15 15:55:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:55:01,441 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:55:01,442 - INFO - 다음 데이터 수집 시간(04:56:00)까지 58.6초 대기...
# 2025-05-16 04:56:00,006 - INFO - === 15:56에 15:55의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:56:00,007 - INFO - 요청 시간 범위: 2025-05-15 15:55:00-04:00 ~ 2025-05-15 15:56:00-04:00 (뉴욕 시간)
# 2025-05-16 04:56:00,232 - WARNING - 해당 시간대(2025-05-15 15:55:00-04:00 ~ 2025-05-15 15:56:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:56:01,445 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:56:01,446 - INFO - 다음 데이터 수집 시간(04:57:00)까지 58.6초 대기...
# 2025-05-16 04:57:00,012 - INFO - === 15:57에 15:56의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:57:00,014 - INFO - 요청 시간 범위: 2025-05-15 15:56:00-04:00 ~ 2025-05-15 15:57:00-04:00 (뉴욕 시간)
# 2025-05-16 04:57:00,229 - WARNING - 해당 시간대(2025-05-15 15:56:00-04:00 ~ 2025-05-15 15:57:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:57:01,433 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:57:01,434 - INFO - 다음 데이터 수집 시간(04:58:00)까지 58.6초 대기...
# 2025-05-16 04:58:00,002 - INFO - === 15:58에 15:57의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:58:00,003 - INFO - 요청 시간 범위: 2025-05-15 15:57:00-04:00 ~ 2025-05-15 15:58:00-04:00 (뉴욕 시간)
# 2025-05-16 04:58:00,232 - WARNING - 해당 시간대(2025-05-15 15:57:00-04:00 ~ 2025-05-15 15:58:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:58:01,440 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:58:01,440 - INFO - 다음 데이터 수집 시간(04:59:00)까지 58.6초 대기...
# 2025-05-16 04:59:00,013 - INFO - === 15:59에 15:58의 1분봉 데이터 수집 중... ===
# 2025-05-16 04:59:00,015 - INFO - 요청 시간 범위: 2025-05-15 15:58:00-04:00 ~ 2025-05-15 15:59:00-04:00 (뉴욕 시간)
# 2025-05-16 04:59:00,230 - WARNING - 해당 시간대(2025-05-15 15:58:00-04:00 ~ 2025-05-15 15:59:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 04:59:01,433 - INFO - 시장 열림. 마감 예정 시간: 2025-05-15 12:00:00-04:00 (뉴욕 시간)
# 2025-05-16 04:59:01,434 - INFO - 다음 데이터 수집 시간(05:00:00)까지 58.6초 대기...
# 2025-05-16 05:00:00,009 - INFO - === 16:00에 15:59의 1분봉 데이터 수집 중... ===
# 2025-05-16 05:00:00,010 - INFO - 요청 시간 범위: 2025-05-15 15:59:00-04:00 ~ 2025-05-15 16:00:00-04:00 (뉴욕 시간)
# 2025-05-16 05:00:00,231 - WARNING - 해당 시간대(2025-05-15 15:59:00-04:00 ~ 2025-05-15 16:00:00-04:00)의 데이터가 없습니다. 시장이 열려있는지 확인하세요.
# 2025-05-16 05:00:01,443 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 05:00:01,443 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 05:15:02,325 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 05:15:02,326 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 05:30:03,224 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 05:30:03,224 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 05:45:04,116 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 05:45:04,117 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 06:00:05,059 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 06:00:05,060 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 06:15:05,953 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 06:15:05,955 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 06:30:06,880 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 06:30:06,881 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 06:45:07,810 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 06:45:07,811 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 07:00:08,701 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 07:00:08,702 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 07:15:09,631 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 07:15:09,631 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 07:30:10,546 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 07:30:10,547 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 07:45:11,396 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 07:45:11,397 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 08:00:12,290 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 08:00:12,290 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 08:15:13,197 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 08:15:13,198 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 08:30:14,025 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 08:30:14,026 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 08:45:14,852 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 08:45:14,853 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 09:00:15,731 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 09:00:15,731 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 09:15:16,635 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 09:15:16,635 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 09:30:17,510 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 09:30:17,511 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
# 2025-05-16 09:45:18,354 - INFO - 시장 닫힘. 개장 예정 시간: 2025-05-16 05:30:00-04:00 (뉴욕 시간)
# 2025-05-16 09:45:18,354 - WARNING - 현재 미국 주식 시장이 닫혀 있습니다.
